# %% [markdown]
# # Geoapify Melbourne Locations
# ## Supermarkets

# %%
# Dependencies
import requests
import json
import pandas as pd

# Import the API key
from config import geoapify_key

# %%
# Set the parameters for the type of place - supermarket
categories = "commercial.supermarket"

# Set the parameters for the type of search of Melbourne (incl all Municipalities)
filters = "place:51397cf9ca8e286240593190f739f8ec42c0f00101f9016cca400000000000c002089203094d656c626f75726e65"
limit = 500

# Set up a parameters dictionary
params = {
    "categories": categories,
    "limit": limit,
    "filter": filters,
    "apiKey": geoapify_key
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# Run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://api.geoapify.com/v2/places?categories=commercial.supermarket&limit=500&filter=place%3A51397cf9ca8e286240593190f739f8ec42c0f00101f9016cca400000000000c002089203094d656c626f75726e65&apiKey=79372d4c67c34669935344d46743808f

# %%
# Convert response to JSON
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.5061028,
#                     -37.65597490049575
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Spiral Tubes",
#                 "address_line2": "6-8 Ardill Street, Melbourne VIC 3777, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "6-8",
#                         "addr:postcode": 3777,
#                         "addr:state": "VIC",
#                         "addr:street": "Ardill Street",
#                         "addr:suburb": "Healesville",
#                         "description": "Spiral Tubes Pty Ltd are an agricultural manufacturer of spiral tubes and spiral flighting supplying farmers and agri wholesalers and retailers Australia wide.",
#                         "email": "rickc@spiraltubes.com.au",
#                         "fax": "+61 3 5962 5617",
#                         "image": "https://s3.us-west-2.amazonaws.com/brownbook-storage/images/s3-df45a29a-6774-4343-b3f8-2e6528c536f5.jpg?w=1920&q=75",
#                         "name": "Spiral Tubes",
#                         "opening_hours": "Mo-Fr 07:00-15:30",
#                         "osm_id": 9733184984,
#                         "osm_type": "n",
#                         "phone": "+61 3 5962 5072",
#                         "shop": "supermarket",
#                         "start_date": 2009,
#                         "website": "https://www.spiraltubes.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Spiral Tubes, 6-8 Ardill Street, Melbourne VIC 3777, Australia",
#                 "housenumber": "6-8",
#                 "lat": -37.6559749,
#                 "lon": 145.5061028,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "Spiral Tubes",
#                 "place_id": "5140cd7ffe313062405924504cfcf6d342c0f00103f901d89d24440200000092030c53706972616c205475626573",
#                 "postcode": "3777",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Ardill Street",
#                 "town": "Healesville"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.29369131496324,
#                     -37.88945561829044
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "1038-1042 Burwood Highway, Ferntree Gully VIC 3156, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "1038-1042",
#                         "addr:street": "Burwood Highway",
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "building": "yes",
#                         "layer": 1,
#                         "name": "Woolworths",
#                         "opening_hours": "24/7",
#                         "osm_id": 32079895,
#                         "osm_type": "w",
#                         "phone": "+61 3 8756 2416",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Woolworths, 1038-1042 Burwood Highway, Ferntree Gully VIC 3156, Australia",
#                 "housenumber": "1038-1042",
#                 "lat": -37.88943505,
#                 "lon": 145.29366295946193,
#                 "municipality": "City of Knox",
#                 "name": "Woolworths",
#                 "place_id": "515d1c54eb652962405984e683aed9f142c0f00102f9011780e9010000000092030a576f6f6c776f72746873",
#                 "postcode": "3156",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Burwood Highway",
#                 "suburb": "Ferntree Gully"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.16109745768674,
#                     -38.11026798195526
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "ALDI",
#                 "address_line2": "493 Frankston-Dandenong Road, Carrum Downs VIC 3201, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 493,
#                         "addr:street": "Frankston-Dandenong Road",
#                         "brand": "ALDI",
#                         "brand:wikidata": "Q125054",
#                         "brand:wikipedia": "en:Aldi",
#                         "building": "retail",
#                         "check_date:opening_hours": "2023-05-05",
#                         "full_name": "ALDI Carrum Downs",
#                         "landuse": "retail",
#                         "name": "ALDI",
#                         "opening_hours": "Mo-Su 08:30-20:00",
#                         "osm_id": 32742473,
#                         "osm_type": "w",
#                         "phone": "+61 13 25 34",
#                         "shop": "supermarket",
#                         "website": "https://store.aldi.com.au/vic/carrum-downs/493-frankston-dandenong-road",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "ALDI, 493 Frankston-Dandenong Road, Carrum Downs VIC 3201, Australia",
#                 "housenumber": "493",
#                 "lat": -38.1102384,
#                 "lon": 145.16103415813782,
#                 "municipality": "City of Frankston",
#                 "name": "ALDI",
#                 "place_id": "517707dbb527256240599a25e0421d0e43c0f00102f901499cf30100000000920304414c4449",
#                 "postcode": "3201",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Frankston-Dandenong Road",
#                 "suburb": "Carrum Downs"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.43999018213816,
#                     -37.93274199525773
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Ritchies IGA",
#                 "address_line2": "342 Belgrave - Gembrook Road, Emerald VIC 3791, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 342,
#                         "addr:street": "Belgrave - Gembrook Road",
#                         "building": "yes",
#                         "email": "emerald_manager@ritchies.com.au",
#                         "fax": "+61 3 5968 3690",
#                         "name": "Ritchies IGA",
#                         "opening_hours": "Mo-Sa 07:00-21:00; Su 08:00-20:00",
#                         "osm_id": 32875500,
#                         "osm_type": "w",
#                         "phone": "+61 3 5968 4753",
#                         "shop": "supermarket",
#                         "website": "https://www.ritchies.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Ritchies IGA, 342 Belgrave - Gembrook Road, Emerald VIC 3791, Australia",
#                 "housenumber": "342",
#                 "lat": -37.93276245,
#                 "lon": 145.43996268937804,
#                 "municipality": "Shire of Cardinia",
#                 "name": "Ritchies IGA",
#                 "place_id": "51065b4a66142e6240596e9ef61664f742c0f00102f901eca3f5010000000092030c526974636869657320494741",
#                 "postcode": "3791",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Belgrave - Gembrook Road",
#                 "suburb": "Emerald"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.02928241814928,
#                     -37.80628609240968
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Leo's Fine Food & Wine",
#                 "address_line2": "26 Princess Street, Kew VIC 3101, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 26,
#                         "addr:postcode": 3101,
#                         "addr:state": "VIC",
#                         "addr:street": "Princess Street",
#                         "addr:suburb": "Kew",
#                         "building": "supermarket",
#                         "name": "Leo's Fine Food & Wine",
#                         "opening_hours": "07:00-22:00",
#                         "operator": "Le Max Group Supermarkets",
#                         "osm_id": 38341438,
#                         "osm_type": "w",
#                         "phone": "+613 9853 8314",
#                         "shop": "supermarket",
#                         "website": "https://www.lemaxgroup.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Leo's Fine Food & Wine, 26 Princess Street, Kew VIC 3101, Australia",
#                 "housenumber": "26",
#                 "lat": -37.806275600000006,
#                 "lon": 145.0292848804172,
#                 "municipality": "City of Boroondara",
#                 "name": "Leo's Fine Food & Wine",
#                 "place_id": "519189aee1ef20624059420ff76134e742c0f00102f9013e0b4902000000009203164c656f27732046696e6520466f6f6420262057696e65",
#                 "postcode": "3101",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Princess Street",
#                 "suburb": "Kew"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.22534246779117,
#                     -37.81459857399788
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Costco",
#                 "address_line2": "29 Bond Street, Ringwood VIC 3134, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Ringwood",
#                         "addr:housenumber": 29,
#                         "addr:postcode": 3134,
#                         "addr:state": "VIC",
#                         "addr:street": "Bond Street",
#                         "addr:suburb": "Ringwood",
#                         "brand": "Costco",
#                         "brand:wikidata": "Q715583",
#                         "brand:wikipedia": "en:Costco",
#                         "building": "retail",
#                         "building:levels": 3,
#                         "name": "Costco",
#                         "opening_hours": "Mo-Fr 10:00-20:30,Sa 9:30-18:30,Su 10:00-18:00",
#                         "osm_id": 46634066,
#                         "osm_type": "w",
#                         "phone": "+61 3 8873 6700",
#                         "shop": "wholesale",
#                         "website": "https://www.costco.com.au/",
#                         "wholesale": "supermarket"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact"
#                 ],
#                 "formatted": "Costco, 29 Bond Street, Ringwood VIC 3134, Australia",
#                 "housenumber": "29",
#                 "lat": -37.81443385,
#                 "lon": 145.22540258708432,
#                 "municipality": "City of Maroondah",
#                 "name": "Costco",
#                 "place_id": "5104326801362762405935581dc444e842c0f00102f9015294c70200000000920306436f7374636f",
#                 "postcode": "3134",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Bond Street",
#                 "suburb": "Ringwood"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.19146248386858,
#                     -38.30629386638937
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coles",
#                 "address_line2": "15 Church Street, Melbourne VIC 3915, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 15,
#                         "addr:postcode": 3915,
#                         "addr:state": "VIC",
#                         "addr:street": "Church Street",
#                         "addr:suburb": "Hastings",
#                         "brand": "Coles",
#                         "brand:wikidata": "Q1108172",
#                         "brand:wikipedia": "en:Coles Supermarkets",
#                         "building": "retail",
#                         "name": "Coles",
#                         "opening_hours": "Mo-Su 6:00-22:00",
#                         "operator": "Coles Group",
#                         "operator:wikidata": "Q1339055",
#                         "osm_id": 51968747,
#                         "osm_type": "w",
#                         "phone": "+61 3 5979 1700",
#                         "shop": "supermarket",
#                         "website": "https://www.coles.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Coles, 15 Church Street, Melbourne VIC 3915, Australia",
#                 "housenumber": "15",
#                 "lat": -38.306256149999996,
#                 "lon": 145.19146488788743,
#                 "municipality": "Shire of Mornington Peninsula",
#                 "name": "Coles",
#                 "place_id": "510c54ee752026624059ca8d2da3342743c0f00102f901ebfa180300000000920305436f6c6573",
#                 "postcode": "3915",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Church Street",
#                 "town": "Hastings"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.97798002737792,
#                     -37.797851175707756
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coles",
#                 "address_line2": "95-103 Johnston Street, Fitzroy VIC 3065, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Fitzroy",
#                         "addr:housenumber": "95-103",
#                         "addr:postcode": 3065,
#                         "addr:state": "VIC",
#                         "addr:street": "Johnston Street",
#                         "addr:suburb": "Fitzroy",
#                         "branch": "Fitzroy",
#                         "brand": "Coles",
#                         "brand:wikidata": "Q1108172",
#                         "brand:wikipedia": "en:Coles Supermarkets",
#                         "building": "yes",
#                         "name": "Coles",
#                         "opening_hours": "Mo-Su 07:00-0:00",
#                         "operator": "Coles Group",
#                         "operator:wikidata": "Q1339055",
#                         "osm_id": 53839901,
#                         "osm_type": "w",
#                         "phone": "+61 3 94152100",
#                         "shop": "supermarket",
#                         "website": "https://www.coles.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Coles, 95-103 Johnston Street, Fitzroy VIC 3065, Australia",
#                 "housenumber": "95-103",
#                 "lat": -37.79778295,
#                 "lon": 144.97799202475238,
#                 "municipality": "City of Yarra",
#                 "name": "Coles",
#                 "place_id": "515737c59c4b1f624059b75ec1fc1fe642c0f00102f9011d88350300000000920305436f6c6573",
#                 "postcode": "3065",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Johnston Street",
#                 "suburb": "Fitzroy"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.26269209713917,
#                     -37.84091092914994
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "659 Mountain Highway, Bayswater VIC 3153, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 659,
#                         "addr:postcode": 3153,
#                         "addr:state": "VIC",
#                         "addr:street": "Mountain Highway",
#                         "addr:suburb": "Bayswater",
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "building": "retail",
#                         "name": "Woolworths",
#                         "opening_hours": "Mo-Su 07:00-23:00",
#                         "operator": "Woolworths Group",
#                         "operator:wikidata": "Q607272",
#                         "osm_id": 85466397,
#                         "osm_type": "w",
#                         "phone": "+61 3 8756 2413",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Woolworths, 659 Mountain Highway, Bayswater VIC 3153, Australia",
#                 "housenumber": "659",
#                 "lat": -37.84083255,
#                 "lon": 145.26266705457908,
#                 "municipality": "City of Knox",
#                 "name": "Woolworths",
#                 "place_id": "512cc441f9672862405924c625f8a2eb42c0f00102f9011d1d18050000000092030a576f6f6c776f72746873",
#                 "postcode": "3153",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Mountain Highway",
#                 "suburb": "Bayswater"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.27530914048594,
#                     -37.88368963540664
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coles",
#                 "address_line2": "1880 Ferntree Gully Road, Ferntree Gully VIC 3156, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 1880,
#                         "addr:street": "Ferntree Gully Road",
#                         "brand": "Coles",
#                         "brand:wikidata": "Q1108172",
#                         "brand:wikipedia": "en:Coles Supermarkets",
#                         "building": "retail",
#                         "full_name": "Coles Mountain Gate",
#                         "name": "Coles",
#                         "opening_hours": "Mo-Su 06:00-22:00",
#                         "osm_id": 90625912,
#                         "osm_type": "w",
#                         "phone": "+61 3 9758 5432",
#                         "shop": "supermarket",
#                         "website": "https://www.coles.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Coles, 1880 Ferntree Gully Road, Ferntree Gully VIC 3156, Australia",
#                 "housenumber": "1880",
#                 "lat": -37.8837523,
#                 "lon": 145.27531479160325,
#                 "municipality": "City of Knox",
#                 "name": "Coles",
#                 "place_id": "51aa551d55cf286240595ef1f1bd1cf142c0f00102f90178d7660500000000920305436f6c6573",
#                 "postcode": "3156",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Ferntree Gully Road",
#                 "suburb": "Ferntree Gully"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.35814164629178,
#                     -37.93169481762014
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "IGA",
#                 "address_line2": "151 Belgrave - Hallam Road, Belgrave South VIC 3160, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 151,
#                         "addr:street": "Belgrave - Hallam Road",
#                         "building": "retail",
#                         "name": "IGA",
#                         "opening_hours": "Mo-Sa 07:00-20:00; Su 08:00-20:00",
#                         "osm_id": 104656696,
#                         "osm_type": "w",
#                         "phone": "+61 3 9754 2293",
#                         "shop": "supermarket",
#                         "website": "https://www.iga.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "IGA, 151 Belgrave - Hallam Road, Belgrave South VIC 3160, Australia",
#                 "housenumber": "151",
#                 "lat": -37.93169485,
#                 "lon": 145.35814164445577,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "IGA",
#                 "place_id": "51154578e5752b624059fec399c641f742c0f00102f90138ef3c0600000000920303494741",
#                 "postcode": "3160",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Belgrave - Hallam Road",
#                 "suburb": "Belgrave South"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.35273422584493,
#                     -37.90955329466377
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "16-29 Burwood Highway, Belgrave VIC 3160, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "16-29",
#                         "addr:street": "Burwood Highway",
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "building": "retail",
#                         "name": "Woolworths",
#                         "opening_hours": "Mo-Su 07:00-22:00",
#                         "osm_id": 107692700,
#                         "osm_type": "w",
#                         "phone": "+61 3 8756 2410",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "Woolworths, 16-29 Burwood Highway, Belgrave VIC 3160, Australia",
#                 "housenumber": "16-29",
#                 "lat": -37.90952660000001,
#                 "lon": 145.35269541850963,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "Woolworths",
#                 "place_id": "51e2854999492b62405965460b3e6cf442c0f00102f9019c426b060000000092030a576f6f6c776f72746873",
#                 "postcode": "3160",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Burwood Highway",
#                 "suburb": "Belgrave"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.27774135939487,
#                     -37.88374785726844
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "Overland Cruiseway, Ferntree Gully VIC 3156, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "building": "yes",
#                         "full_name": "Woolworths Mountain Gate",
#                         "name": "Woolworths",
#                         "opening_hours": "Mo-Su 06:00-23:00",
#                         "osm_id": 108178136,
#                         "osm_type": "w",
#                         "phone": "+61 3 8756 2440",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Woolworths, Overland Cruiseway, Ferntree Gully VIC 3156, Australia",
#                 "lat": -37.88380015,
#                 "lon": 145.27782054425435,
#                 "municipality": "City of Knox",
#                 "name": "Woolworths",
#                 "place_id": "511febd841e328624059637058a61ef142c0f00102f901d8aa72060000000092030a576f6f6c776f72746873",
#                 "postcode": "3156",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Overland Cruiseway",
#                 "suburb": "Ferntree Gully"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.44530965475536,
#                     -37.927597584516626
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "383-385 Belgrave - Gembrook Road, Emerald VIC 3782, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "383-385",
#                         "addr:postcode": 3782,
#                         "addr:street": "Belgrave-Gembrook Road",
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "building": "retail",
#                         "name": "Woolworths",
#                         "opening_hours": "Mo-Su 07:00-22:00",
#                         "osm_id": 132983798,
#                         "osm_type": "w",
#                         "phone": "+61 3 5949 4303",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Woolworths, 383-385 Belgrave - Gembrook Road, Emerald VIC 3782, Australia",
#                 "housenumber": "383-385",
#                 "lat": -37.9276341,
#                 "lon": 145.44536502609049,
#                 "municipality": "Shire of Cardinia",
#                 "name": "Woolworths",
#                 "place_id": "518e7808fa3f2e6240597bac8484bbf642c0f00102f901f62bed070000000092030a576f6f6c776f72746873",
#                 "postcode": "3782",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Belgrave - Gembrook Road",
#                 "suburb": "Emerald"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.33119031701213,
#                     -37.90420308984829
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "IGA",
#                 "address_line2": "62-64 Main Street, Upwey VIC 3158, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "62-64",
#                         "addr:street": "Main Street",
#                         "brand": "IGA",
#                         "brand:wikidata": "Q5970945",
#                         "brand:wikipedia": "en:IGA (Australian supermarket group)",
#                         "building": "yes",
#                         "name": "IGA",
#                         "opening_hours": "Mo-Su 07:00-21:00",
#                         "osm_id": 159810917,
#                         "osm_type": "w",
#                         "phone": "+61 3 9754 3013",
#                         "shop": "supermarket",
#                         "website": "https://www.iga.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "IGA, 62-64 Main Street, Upwey VIC 3158, Australia",
#                 "housenumber": "62-64",
#                 "lat": -37.9041693,
#                 "lon": 145.3311823805039,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "IGA",
#                 "place_id": "51358a6f1c992a62405997eb45edbcf342c0f00102f9016585860900000000920303494741",
#                 "postcode": "3158",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Main Street",
#                 "suburb": "Upwey"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.2692915996013,
#                     -37.783285918564665
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Jefferies | Your Local Provedore",
#                 "address_line2": "40-42 Plymouth Road, Croydon Hills VIC 3136, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Croydon",
#                         "addr:housenumber": "40-42",
#                         "addr:postcode": 3136,
#                         "addr:province": "Victoria",
#                         "addr:state": "VIC",
#                         "addr:street": "Plymouth Road",
#                         "addr:suburb": "Croydon Hills",
#                         "building": "yes",
#                         "building:levels": 1,
#                         "name": "Jefferies | Your Local Provedore",
#                         "opening_hours": "Mo-Su 07:30-21:00",
#                         "osm_id": 192855606,
#                         "osm_type": "w",
#                         "phone": "+61 3 9725 3288",
#                         "shop": "supermarket",
#                         "website": "https://www.jefferies.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact"
#                 ],
#                 "formatted": "Jefferies | Your Local Provedore, 40-42 Plymouth Road, Croydon Hills VIC 3136, Australia",
#                 "housenumber": "40-42",
#                 "lat": -37.7832893,
#                 "lon": 145.26929059196186,
#                 "municipality": "City of Maroondah",
#                 "name": "Jefferies | Your Local Provedore",
#                 "place_id": "5101ac6a099e2862405987d385b642e442c0f00102f90136be7e0b000000009203204a6566666572696573207c20596f7572204c6f63616c2050726f7665646f7265",
#                 "postcode": "3136",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Plymouth Road",
#                 "suburb": "Croydon Hills"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.00285963953903,
#                     -37.737148492885666
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "334 Murray Road, Preston VIC 3072, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.supermarket",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Preston",
#                         "addr:housenumber": 334,
#                         "addr:postcode": 3072,
#                         "addr:street": "Murray Road",
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "building": "yes",
#                         "full_name": "Woolworths Preston",
#                         "name": "Woolworths",
#                         "opening_hours": "Mo-Su 06:00-00:00",
#                         "osm_id": 220483801,
#                         "osm_type": "w",
#                         "phone": "+61 3 94782022",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au/",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "Woolworths, 334 Murray Road, Preston VIC 3072, Australia",
#                 "housenumber": "334",
#                 "lat": -37.7371422,
#                 "lon": 145.00283395229087,
#                 "municipality": "City of Darebin",
#                 "name": "Woolworths",
#                 "place_id": "518d49196d1720624059ac9ebee15ade42c0f00102f901d950240d0000000092030a576f6f6c776f72746873",
#                 "postcode": "3072",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Murray Road",
#                 "suburb": "Preston"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.2497208,
#                     -37.89437690054852
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "IGA",
#                 "address_line2": "1579 Ferntree Gully Road, Knoxfield VIC 3180, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 1579,
#                         "addr:street": "Ferntree Gully Road",
#                         "name": "IGA",
#                         "opening_hours": "Mo-Su 08:00-20:00",
#                         "osm_id": 304476989,
#                         "osm_type": "n",
#                         "phone": "+61 3 9763 4630",
#                         "shop": "supermarket",
#                         "website": "https://www.iga.com.au"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "IGA, 1579 Ferntree Gully Road, Knoxfield VIC 3180, Australia",
#                 "housenumber": "1579",
#                 "lat": -37.8943769,
#                 "lon": 145.2497208,
#                 "municipality": "City of Knox",
#                 "name": "IGA",
#                 "place_id": "5131a479b6fd27624059ae1339f17af242c0f00103f9013df3251200000000920303494741",
#                 "postcode": "3180",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Ferntree Gully Road",
#                 "suburb": "Knoxfield"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.9497728451335,
#                     -37.80459457286306
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "North Melbourne Supa IGA + Liquor",
# ...
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Woolworths, 1099 - 1169 Pascoe Vale Road, Broadmeadows VIC 3047, Australia",
#                 "housenumber": "1099 - 1169",
#                 "lat": -37.6803737,
#                 "lon": 144.9182109,
#                 "municipality": "City of Hume",
#                 "name": "Woolworths",
#                 "place_id": "51954ad3fb611d624059095b447c16d742c0f00103f90113a77a810000000092030a576f6f6c776f72746873",
#                 "postcode": "3047",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Pascoe Vale Road",
#                 "suburb": "Broadmeadows"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.9186507,
#                     -37.67968600050106
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coles",
#                 "address_line2": "1099-1169 Pascoe Vale Road, Broadmeadows VIC 3047, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "1099-1169",
#                         "addr:street": "Pascoe Vale Road",
#                         "brand": "Coles",
#                         "brand:wikidata": "Q1108172",
#                         "brand:wikipedia": "en:Coles Supermarkets",
#                         "name": "Coles",
#                         "osm_id": 2172299040,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.coles.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Coles, 1099-1169 Pascoe Vale Road, Broadmeadows VIC 3047, Australia",
#                 "housenumber": "1099-1169",
#                 "lat": -37.679686,
#                 "lon": 144.9186507,
#                 "municipality": "City of Hume",
#                 "name": "Coles",
#                 "place_id": "51521e2796651d624059bdd96bf3ffd642c0f00103f90120a77a8100000000920305436f6c6573",
#                 "postcode": "3047",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Pascoe Vale Road",
#                 "suburb": "Broadmeadows"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.3133008,
#                     -37.75695680051825
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coles",
#                 "address_line2": "239-241 Maroondah Highway, Chirnside Park VIC 3116, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Coles",
#                         "brand:wikidata": "Q1108172",
#                         "brand:wikipedia": "en:Coles Supermarkets",
#                         "name": "Coles",
#                         "osm_id": 2177939910,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.coles.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Coles, 239-241 Maroondah Highway, Chirnside Park VIC 3116, Australia",
#                 "housenumber": "239-241",
#                 "lat": -37.7569568,
#                 "lon": 145.3133008,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "Coles",
#                 "place_id": "51f139668f062a624059f85adff5e3e042c0f00103f901c6b9d08100000000920305436f6c6573",
#                 "postcode": "3116",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Maroondah Highway",
#                 "suburb": "Chirnside Park"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.9573651,
#                     -37.83065640053454
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "111 Cecil Street, South Melbourne VIC 3205, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "name": "Woolworths",
#                         "osm_id": 2184871393,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Woolworths, 111 Cecil Street, South Melbourne VIC 3205, Australia",
#                 "housenumber": "111",
#                 "lat": -37.8306564,
#                 "lon": 144.9573651,
#                 "municipality": "City of Port Phillip",
#                 "name": "Woolworths",
#                 "place_id": "519e5a22bca21e6240592441edf252ea42c0f00103f901e17d3a820000000092030a576f6f6c776f72746873",
#                 "postcode": "3205",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Cecil Street",
#                 "suburb": "South Melbourne"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.9384264,
#                     -37.597671500482676
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "Hanson Road, Craigieburn VIC 3064, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "name": "Woolworths",
#                         "osm_id": 2186428219,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Woolworths, Hanson Road, Craigieburn VIC 3064, Australia",
#                 "lat": -37.5976715,
#                 "lon": 144.9384264,
#                 "municipality": "City of Hume",
#                 "name": "Woolworths",
#                 "place_id": "517f36cd96071e6240598429ee7f80cc42c0f00103f9013b3f52820000000092030a576f6f6c776f72746873",
#                 "postcode": "3064",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Hanson Road",
#                 "suburb": "Craigieburn"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.2177309,
#                     -37.98747730056878
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "McCrae Street, Dandenong VIC 3177, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "name": "Woolworths",
#                         "osm_id": 2196694206,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Woolworths, McCrae Street, Dandenong VIC 3177, Australia",
#                 "lat": -37.9874773,
#                 "lon": 145.2177309,
#                 "municipality": "City of Greater Dandenong",
#                 "name": "Woolworths",
#                 "place_id": "5184dacaa6f7266240591dbefba765fe42c0f00103f901bee4ee820000000092030a576f6f6c776f72746873",
#                 "postcode": "3177",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "McCrae Street",
#                 "suburb": "Dandenong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.8896964,
#                     -37.77328590052188
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Woolworths",
#                 "address_line2": "120-200 Rosamond Road, Maribyrnong VIC 3032, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Woolworths",
#                         "brand:wikidata": "Q3249145",
#                         "brand:wikipedia": "en:Woolworths Supermarkets",
#                         "name": "Woolworths",
#                         "osm_id": 2206160219,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.woolworths.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Woolworths, 120-200 Rosamond Road, Maribyrnong VIC 3032, Australia",
#                 "housenumber": "120-200",
#                 "lat": -37.7732859,
#                 "lon": 144.8896964,
#                 "municipality": "City of Maribyrnong",
#                 "name": "Woolworths",
#                 "place_id": "51ceab9564781c62405985994a08fbe242c0f00103f9015b557f830000000092030a576f6f6c776f72746873",
#                 "postcode": "3032",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Rosamond Road",
#                 "suburb": "Maribyrnong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.93235639999997,
#                     -37.6383870004918
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coles",
#                 "address_line2": "250 Somerton Road, Roxburgh Park VIC 3048, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.supermarket"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 250,
#                         "addr:street": "Somerton Road",
#                         "brand": "Coles",
#                         "brand:wikidata": "Q1108172",
#                         "brand:wikipedia": "en:Coles Supermarkets",
#                         "name": "Coles",
#                         "osm_id": 2268930955,
#                         "osm_type": "n",
#                         "shop": "supermarket",
#                         "website": "https://www.coles.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "formatted": "Coles, 250 Somerton Road, Roxburgh Park VIC 3048, Australia",
#                 "housenumber": "250",
#                 "lat": -37.638387,
#                 "lon": 144.9323564,
#                 "municipality": "City of Hume",
#                 "name": "Coles",
#                 "place_id": "51ebc616ddd51d624059e3a64caab6d142c0f00103f9018b233d8700000000920305436f6c6573",
#                 "postcode": "3048",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Somerton Road",
#                 "suburb": "Roxburgh Park"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Create an empty list to store supermarket data
market_data = []

# Check if "features" key exists in the JSON response
if "features" in places_data:
    # Loop through all the hospitals
    for feature in places_data["features"]:
        # Retrieve the desired information for each supermarket
        properties = feature.get("properties", {})
        name = properties.get("name", None)
        address = properties.get("address_line2", None)
        municipality = properties.get("municipality", None)
        suburb = properties.get("suburb", None)
        postcode = properties.get("postcode", None)
        latitude = properties.get("lat", None)
        longitude = properties.get("lon", None)

        # Append the hospital data to the list
        market_data.append({
            "NAME": name,
            "Address": address,
            "Municipality": municipality,
            "Suburb": suburb,
            "POST_CODE": postcode,
            "Latitude":latitude,
            "Longitude":longitude
        })

    # Create a DataFrame from the hospital data
    market_df = pd.DataFrame(market_data)

else:
    print("No supermarket data found.")
    
market_df
# Out:
#                        NAME  \
# 0              Spiral Tubes
# 1                Woolworths
# 2                      ALDI
# 3              Ritchies IGA
# 4    Leo's Fine Food & Wine
# ..                      ...
# 495              Woolworths
# 496              Woolworths
# 497              Woolworths
# 498              Woolworths
# 499                   Coles
#
#                                                Address  \
# 0     6-8 Ardill Street, Melbourne VIC 3777, Australia
# 1    1038-1042 Burwood Highway, Ferntree Gully VIC ...
# 2    493 Frankston-Dandenong Road, Carrum Downs VIC...
# 3    342 Belgrave - Gembrook Road, Emerald VIC 3791...
# 4          26 Princess Street, Kew VIC 3101, Australia
# ..                                                 ...
# 495  111 Cecil Street, South Melbourne VIC 3205, Au...
# 496       Hanson Road, Craigieburn VIC 3064, Australia
# 497       McCrae Street, Dandenong VIC 3177, Australia
# 498  120-200 Rosamond Road, Maribyrnong VIC 3032, A...
# 499  250 Somerton Road, Roxburgh Park VIC 3048, Aus...
#
#                   Municipality           Suburb POST_CODE   Latitude  \
# 0        Shire of Yarra Ranges             None      3777 -37.655975
# 1                 City of Knox   Ferntree Gully      3156 -37.889435
# 2            City of Frankston     Carrum Downs      3201 -38.110238
# 3            Shire of Cardinia          Emerald      3791 -37.932762
# 4           City of Boroondara              Kew      3101 -37.806276
# ..                         ...              ...       ...        ...
# 495       City of Port Phillip  South Melbourne      3205 -37.830656
# 496               City of Hume      Craigieburn      3064 -37.597671
# 497  City of Greater Dandenong        Dandenong      3177 -37.987477
# 498        City of Maribyrnong      Maribyrnong      3032 -37.773286
# 499               City of Hume    Roxburgh Park      3048 -37.638387
#
#       Longitude
# 0    145.506103
# 1    145.293663
# 2    145.161034
# 3    145.439963
# 4    145.029285
# ..          ...
# 495  144.957365
# 496  144.938426
# 497  145.217731
# 498  144.889696
# 499  144.932356
#
# [500 rows x 7 columns]

# %%
#Import mapping file - use to filter to sample postcodes for further analysis
# Specify the file path and sheet name
file_path = "Resources/Melbourne Postcodes.xlsx"
sheet_name = "Mapping"

# Read the specified sheet into a DataFrame
melb_postcodes_df = pd.read_excel(file_path, sheet_name=sheet_name)
melb_postcodes_df= melb_postcodes_df.dropna(subset=['ABS_SA2_KEY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['HOUSE_LOCALITY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['SCHOOL_POST_CODE'])

#convert POST_CODE to string
melb_postcodes_df['POST_CODE'] = melb_postcodes_df['POST_CODE'].astype(str)
# Display the DataFrame
melb_postcodes_df
# Out:
#                                      MUNICIPALITY             CITY_SHIRE  \
# 0     Inner City municipalities and their suburbs      City of Melbourne
# 2     Inner City municipalities and their suburbs          City of Yarra
# 6       Northern municipalities and their suburbs  City of Moonee Valley
# 7       Northern municipalities and their suburbs  City of Moonee Valley
# 10    Inner City municipalities and their suburbs      City of Melbourne
# ...                                           ...                    ...
# 997      Western municipalities and their suburbs        City of Wyndham
# 1000     Western municipalities and their suburbs        City of Wyndham
# 1003     Western municipalities and their suburbs        City of Wyndham
# 1005     Western municipalities and their suburbs         City of Melton
# 1008     Western municipalities and their suburbs        City of Wyndham
#
#      SUBURB_GROUP    RURAL_TOWNSHIP POST_CODE  \
# 0           Inner               NaN      3053
# 2           Inner               NaN      3054
# 6             Mid               NaN      3031
# 7             Mid               NaN      3031
# 10          Inner               NaN      3051
# ...           ...               ...       ...
# 997         Outer               NaN      3030
# 1000        Outer               NaN      3030
# 1003        Outer               NaN      3024
# 1005        Outer  Rural localities      3338
# 1008        Outer  Rural localities      3024
#
#                                   ABS_SA2_KEY   HOUSE_LOCALITY  \
# 0                          206041117: Carlton          CARLTON
# 2     206071140: Carlton North - Princes Hill    CARLTON NORTH
# 6                       206031115: Flemington       FLEMINGTON
# 7                       206031115: Flemington       KENSINGTON
# 10                 206041506: North Melbourne  NORTH MELBOURNE
# ...                                       ...              ...
# 997                       213011570: Derrimut         WERRIBEE
# 1000                      213011570: Derrimut   WERRIBEE SOUTH
# 1003        213051579: Manor Lakes - Quandong     WYNDHAM VALE
# 1005                    213041571: Brookfield        EYNESBURY
# 1008        213051579: Manor Lakes - Quandong        MAMBOURIN
#
#       SCHOOL_POST_CODE      SUBURB_NAME                           COMMENTS  \
# 0               3053.0          Carlton                                NaN
# 2               3054.0    Carlton North          Shared with City of Yarra
# 6               3031.0       Flemington  Shared with City of Moonee Valley
# 7               3031.0       Kensington                                NaN
# 10              3051.0  North Melbourne  Shared with City of Moonee Valley
# ...                ...              ...                                ...
# 997             3030.0         Werribee                                NaN
# 1000            3030.0   Werribee South                                NaN
# 1003            3024.0     Wyndham Vale                                NaN
# 1005            3338.0        Eynesbury    Shared with the Shire of Melton
# 1008            3024.0        Mambourin                                NaN
#
#                                SUBURB_POSTCODE_COMMENTS
# 0                                          Carlton 3053
# 2        Carlton North 3054 (Shared with City of Yarra)
# 6     Flemington 3031 (Shared with City of Moonee Va...
# 7                                       Kensington 3031
# 10    North Melbourne 3051 (Shared with City of Moon...
# ...                                                 ...
# 997                                       Werribee 3030
# 1000                                Werribee South 3030
# 1003                                  Wyndham Vale 3024
# 1005   Eynesbury 3338 (Shared with the Shire of Melton)
# 1008                                     Mambourin 3024
#
# [405 rows x 11 columns]

# %%
# Concatenate SUBURB_NAME values for each POST_CODE
postcode_suburbs_df = melb_postcodes_df.groupby('POST_CODE')['SUBURB_NAME'].agg(lambda x: ', '.join(x)).reset_index()

# Display the resulting DataFrame
postcode_suburbs_df
# Out:
#     POST_CODE                                        SUBURB_NAME
# 0        3003                                     West Melbourne
# 1        3011                                  Footscray, Seddon
# 2        3012  Brooklyn, Brooklyn, Kingsville, Maidstone, Wes...
# 3        3013                  Yarraville, Aintree, Bonnie Brook
# 4        3015               Newport, Spotswood, South Kingsville
# ..        ...                                                ...
# 188      3975                                Lynbrook, Lyndhurst
# 189      3976                                       Hampton Park
# 190      3977  Botanic Ridge, Cranbourne, Cranbourne East, Cr...
# 191      3978                                 Clyde, Clyde North
# 192      3981                                        Koo Wee Rup
#
# [193 rows x 2 columns]

# %%
market_clean_1_df = pd.merge(melb_postcodes_df, market_df, how='inner', on='POST_CODE')

market_clean_1_df= market_clean_1_df.dropna(subset=['HOUSE_LOCALITY'])

columns_to_drop = ["RURAL_TOWNSHIP","ABS_SA2_KEY","HOUSE_LOCALITY","SCHOOL_POST_CODE",
                   "COMMENTS","SUBURB_NAME","SUBURB_POSTCODE_COMMENTS","Address","Municipality"]

market_clean_1_df = market_clean_1_df.drop(columns_to_drop, axis=1)
market_clean_1_df
# Out:
#                                      MUNICIPALITY             CITY_SHIRE  \
# 0     Inner City municipalities and their suburbs      City of Melbourne
# 1     Inner City municipalities and their suburbs          City of Yarra
# 2     Inner City municipalities and their suburbs          City of Yarra
# 3     Inner City municipalities and their suburbs          City of Yarra
# 4       Northern municipalities and their suburbs  City of Moonee Valley
# ...                                           ...                    ...
# 1134     Western municipalities and their suburbs        City of Wyndham
# 1135     Western municipalities and their suburbs        City of Wyndham
# 1136     Western municipalities and their suburbs        City of Wyndham
# 1137     Western municipalities and their suburbs        City of Wyndham
# 1138     Western municipalities and their suburbs        City of Wyndham
#
#      SUBURB_GROUP POST_CODE            NAME         Suburb   Latitude  \
# 0           Inner      3053  King & Godfree        Carlton -37.798456
# 1           Inner      3054       Foodworks  Carlton North -37.788987
# 2           Inner      3054       Foodworks  Carlton North -37.788987
# 3           Inner      3054       Foodworks  Carlton North -37.788987
# 4             Mid      3031       Foodworks     Kensington -37.794331
# ...           ...       ...             ...            ...        ...
# 1134        Outer      3024      Woolworths   Wyndham Vale -37.888021
# 1135        Outer      3024           Coles    Manor Lakes -37.875751
# 1136        Outer      3024            ALDI   Wyndham Vale -37.887484
# 1137        Outer      3024      Woolworths   Wyndham Vale -37.888021
# 1138        Outer      3024           Coles    Manor Lakes -37.875751
#
#        Longitude
# 0     144.967093
# 1     144.976090
# 2     144.976090
# 3     144.976090
# 4     144.929866
# ...          ...
# 1134  144.607229
# 1135  144.614518
# 1136  144.607204
# 1137  144.607229
# 1138  144.614518
#
# [1139 rows x 8 columns]

# %%
unique_count = market_clean_1_df['POST_CODE'].nunique()

# Display the count of unique strings
print(unique_count)
# Out:
# 152

# %%
market_clean_final_df = pd.merge(market_clean_1_df, postcode_suburbs_df, how='inner', on='POST_CODE')
new_column_names = {
    "SUBURB_NAME": "SUBURB_NAMES",
    }
market_clean_final_df = market_clean_final_df.rename(columns=new_column_names)

# Remove duplicates based on the "POST_CODE" column
market_clean_final_df = market_clean_final_df.drop_duplicates(subset='POST_CODE')

# Reset the index and make POST_CODE the new index
market_clean_final_df = market_clean_final_df.set_index('POST_CODE')

# Export cleaned supermarket dataset to a CSV file
market_clean_final_df.to_csv("Cleaned_Data/supermarket_clean_final.csv", index_label="POST_CODE")

market_clean_final_df
# Out:
#                                           MUNICIPALITY             CITY_SHIRE  \
# POST_CODE
# 3053       Inner City municipalities and their suburbs      City of Melbourne
# 3054       Inner City municipalities and their suburbs          City of Yarra
# 3031         Northern municipalities and their suburbs  City of Moonee Valley
# 3051       Inner City municipalities and their suburbs      City of Melbourne
# 3207       Inner City municipalities and their suburbs   City of Port Phillip
# ...                                                ...                    ...
# 3013          Western municipalities and their suburbs    City of Maribyrnong
# 3338          Western municipalities and their suburbs         City of Melton
# 3337          Western municipalities and their suburbs         City of Melton
# 3029          Western municipalities and their suburbs        City of Wyndham
# 3024          Western municipalities and their suburbs        City of Wyndham
#
#           SUBURB_GROUP                               NAME            Suburb  \
# POST_CODE
# 3053             Inner                     King & Godfree           Carlton
# 3054             Inner                          Foodworks     Carlton North
# 3031               Mid                          Foodworks        Kensington
# 3051             Inner  North Melbourne Supa IGA + Liquor   North Melbourne
# 3207             Inner                         About Life    Port Melbourne
# ...                ...                                ...               ...
# 3013               Mid              Alligator Brand Pasta        Yarraville
# 3338             Outer                              Coles      Melton South
# 3337             Outer                               ALDI              None
# 3029             Outer                                IGA  Hoppers Crossing
# 3024             Outer                               ALDI      Wyndham Vale
#
#             Latitude   Longitude  \
# POST_CODE
# 3053      -37.798456  144.967093
# 3054      -37.788987  144.976090
# 3031      -37.794331  144.929866
# 3051      -37.804595  144.949773
# 3207      -37.841070  144.940275
# ...              ...         ...
# 3013      -37.821353  144.896221
# 3338      -37.701731  144.574255
# 3337      -37.683051  144.578872
# 3029      -37.861275  144.674275
# 3024      -37.887484  144.607204
#
#                                                 SUBURB_NAMES
# POST_CODE
# 3053                                                 Carlton
# 3054              Carlton North, Carlton North, Princes Hill
# 3031                                  Flemington, Kensington
# 3051                                         North Melbourne
# 3207             Port Melbourne, Port Melbourne, Garden City
# ...                                                      ...
# 3013                       Yarraville, Aintree, Bonnie Brook
# 3338       Brookfield, Eynesbury, Fraser Rise, Harkness, ...
# 3337                          Kurunjang, Melton, Melton West
# 3029       Truganina, Weir Views, Hoppers Crossing, Tarne...
# 3024                    Manor Lakes, Wyndham Vale, Mambourin
#
# [152 rows x 8 columns]

# %%
# Group the hospitals_clean_final_df by the specified columns and count the occurrences of NAME
market_count_by_postcode_df = market_clean_final_df.groupby(['POST_CODE', 'MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP'])['NAME'].count().reset_index()

# Rename the count column to "Hospital_Count"
market_count_by_postcode_df = market_count_by_postcode_df.rename(columns={'NAME': 'Supermarket_Count'})

# Export the hospital count by postcode to a CSV file
market_count_by_postcode_df.to_csv("Cleaned_Data/supermarket_count_by_postcode_2023.csv", index=False)

# Display the hospital count DataFrame
market_count_by_postcode_df
# Out:
#     POST_CODE                                   MUNICIPALITY  \
# 0        3003    Inner City municipalities and their suburbs
# 1        3011       Western municipalities and their suburbs
# 2        3012       Western municipalities and their suburbs
# 3        3013       Western municipalities and their suburbs
# 4        3016       Western municipalities and their suburbs
# ..        ...                                            ...
# 147      3936  Southeastern municipalities and their suburbs
# 148      3939  Southeastern municipalities and their suburbs
# 149      3975  Southeastern municipalities and their suburbs
# 150      3976  Southeastern municipalities and their suburbs
# 151      3977  Southeastern municipalities and their suburbs
#
#                         CITY_SHIRE SUBURB_GROUP  Supermarket_Count
# 0                City of Melbourne        Inner                  1
# 1              City of Maribyrnong          Mid                  1
# 2              City of Maribyrnong          Mid                  1
# 3              City of Maribyrnong          Mid                  1
# 4              City of Hobsons Bay          Mid                  1
# ..                             ...          ...                ...
# 147  Shire of Mornington Peninsula        Outer                  1
# 148  Shire of Mornington Peninsula        Outer                  1
# 149                  City of Casey        Outer                  1
# 150                  City of Casey        Outer                  1
# 151                  City of Casey        Outer                  1
#
# [152 rows x 5 columns]
