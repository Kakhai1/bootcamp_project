# %% [markdown]
# # Clean Population Data

# %%
# Import the required libraries
import requests
import json
import pandas as pd

# %%
#Import Population Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Resources\ABS_ERP_ASGS2021_1.0.0.csv"
population_df = pd.read_csv(file_path, encoding="utf-8")

columns_to_drop = ["DATAFLOW","MEASURE: Measure","UNIT_MEASURE: Unit of Measure",
                   "OBS_STATUS: Observation Status","OBS_COMMENT: Observation Comment"]
population_df = population_df.drop(columns_to_drop, axis=1)

new_column_names = {
    "SEX: Sex": "Gender",
    "AGE: Age": "Age",
    "REGION_TYPE: Geography Level":"Geography_Level",
    "ASGS_2021: Region":"ABS_SA2_KEY",
    "FREQ: Frequency":"Frequency",
    "TIME_PERIOD: Time Period":"Year",
    "OBS_VALUE": "Estimated_Resident_Population"
    }
population_df = population_df.rename(columns=new_column_names)
population_df
# Out:
#              Gender                Age  \
# 0        3: Persons      TOT: All ages
# 1        3: Persons      TOT: All ages
# 2        3: Persons      TOT: All ages
# 3        3: Persons      TOT: All ages
# 4        3: Persons      TOT: All ages
# ...             ...                ...
# 3482068  2: Females  8599: 85 and over
# 3482069  2: Females  8599: 85 and over
# 3482070  2: Females  8599: 85 and over
# 3482071  2: Females  8599: 85 and over
# 3482072  2: Females  8599: 85 and over
#
#                                        Geography_Level  \
# 0                                       AUS: Australia
# 1                                       AUS: Australia
# 2                                       AUS: Australia
# 3                                       AUS: Australia
# 4                                       AUS: Australia
# ...                                                ...
# 3482068  GCCSA: Greater Capital City Statistical Areas
# 3482069  GCCSA: Greater Capital City Statistical Areas
# 3482070  GCCSA: Greater Capital City Statistical Areas
# 3482071  GCCSA: Greater Capital City Statistical Areas
# 3482072  GCCSA: Greater Capital City Statistical Areas
#
#                       ABS_SA2_KEY  Frequency  Year  \
# 0                  AUS: Australia  A: Annual  2001
# 1                  AUS: Australia  A: Annual  2002
# 2                  AUS: Australia  A: Annual  2003
# 3                  AUS: Australia  A: Annual  2004
# 4                  AUS: Australia  A: Annual  2005
# ...                           ...        ...   ...
# 3482068  9OTER: Other Territories  A: Annual  2017
# 3482069  9OTER: Other Territories  A: Annual  2018
# 3482070  9OTER: Other Territories  A: Annual  2019
# 3482071  9OTER: Other Territories  A: Annual  2020
# 3482072  9OTER: Other Territories  A: Annual  2021
#
#          Estimated_Resident_Population
# 0                             19274701
# 1                             19495210
# 2                             19720737
# 3                             19932722
# 4                             20176844
# ...                                ...
# 3482068                             28
# 3482069                             28
# 3482070                             32
# 3482071                             36
# 3482072                             34
#
# [3482073 rows x 7 columns]

# %%
#Import mapping file - use to filter to sample postcodes for further analysis
# Specify the file path and sheet name
file_path = "Resources/Melbourne Postcodes.xlsx"
sheet_name = "Mapping"

# Read the specified sheet into a DataFrame
melb_postcodes_df = pd.read_excel(file_path, sheet_name=sheet_name)
melb_postcodes_df= melb_postcodes_df.dropna(subset=['ABS_SA2_KEY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['HOUSE_LOCALITY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['SCHOOL_POST_CODE'])

# Display the DataFrame
melb_postcodes_df
# Out:
#                                      MUNICIPALITY             CITY_SHIRE  \
# 0     Inner City municipalities and their suburbs      City of Melbourne
# 2     Inner City municipalities and their suburbs          City of Yarra
# 6       Northern municipalities and their suburbs  City of Moonee Valley
# 7       Northern municipalities and their suburbs  City of Moonee Valley
# 10    Inner City municipalities and their suburbs      City of Melbourne
# ...                                           ...                    ...
# 997      Western municipalities and their suburbs        City of Wyndham
# 1000     Western municipalities and their suburbs        City of Wyndham
# 1003     Western municipalities and their suburbs        City of Wyndham
# 1005     Western municipalities and their suburbs         City of Melton
# 1008     Western municipalities and their suburbs        City of Wyndham
#
#      SUBURB_GROUP    RURAL_TOWNSHIP  POST_CODE  \
# 0           Inner               NaN       3053
# 2           Inner               NaN       3054
# 6             Mid               NaN       3031
# 7             Mid               NaN       3031
# 10          Inner               NaN       3051
# ...           ...               ...        ...
# 997         Outer               NaN       3030
# 1000        Outer               NaN       3030
# 1003        Outer               NaN       3024
# 1005        Outer  Rural localities       3338
# 1008        Outer  Rural localities       3024
#
#                                   ABS_SA2_KEY   HOUSE_LOCALITY  \
# 0                          206041117: Carlton          CARLTON
# 2     206071140: Carlton North - Princes Hill    CARLTON NORTH
# 6                       206031115: Flemington       FLEMINGTON
# 7                       206031115: Flemington       KENSINGTON
# 10                 206041506: North Melbourne  NORTH MELBOURNE
# ...                                       ...              ...
# 997                       213011570: Derrimut         WERRIBEE
# 1000                      213011570: Derrimut   WERRIBEE SOUTH
# 1003        213051579: Manor Lakes - Quandong     WYNDHAM VALE
# 1005                    213041571: Brookfield        EYNESBURY
# 1008        213051579: Manor Lakes - Quandong        MAMBOURIN
#
#       SCHOOL_POST_CODE      SUBURB_NAME                           COMMENTS  \
# 0               3053.0          Carlton                                NaN
# 2               3054.0    Carlton North          Shared with City of Yarra
# 6               3031.0       Flemington  Shared with City of Moonee Valley
# 7               3031.0       Kensington                                NaN
# 10              3051.0  North Melbourne  Shared with City of Moonee Valley
# ...                ...              ...                                ...
# 997             3030.0         Werribee                                NaN
# 1000            3030.0   Werribee South                                NaN
# 1003            3024.0     Wyndham Vale                                NaN
# 1005            3338.0        Eynesbury    Shared with the Shire of Melton
# 1008            3024.0        Mambourin                                NaN
#
#                                SUBURB_POSTCODE_COMMENTS
# 0                                          Carlton 3053
# 2        Carlton North 3054 (Shared with City of Yarra)
# 6     Flemington 3031 (Shared with City of Moonee Va...
# 7                                       Kensington 3031
# 10    North Melbourne 3051 (Shared with City of Moon...
# ...                                                 ...
# 997                                       Werribee 3030
# 1000                                Werribee South 3030
# 1003                                  Wyndham Vale 3024
# 1005   Eynesbury 3338 (Shared with the Shire of Melton)
# 1008                                     Mambourin 3024
#
# [405 rows x 11 columns]

# %%
# Concatenate SUBURB_NAME values for each POST_CODE
postcode_suburbs_df = melb_postcodes_df.groupby('POST_CODE')['SUBURB_NAME'].agg(lambda x: ', '.join(x)).reset_index()

# Display the resulting DataFrame
postcode_suburbs_df
# Out:
#      POST_CODE                                        SUBURB_NAME
# 0         3003                                     West Melbourne
# 1         3011                                  Footscray, Seddon
# 2         3012  Brooklyn, Brooklyn, Kingsville, Maidstone, Wes...
# 3         3013                  Yarraville, Aintree, Bonnie Brook
# 4         3015               Newport, Spotswood, South Kingsville
# ..         ...                                                ...
# 188       3975                                Lynbrook, Lyndhurst
# 189       3976                                       Hampton Park
# 190       3977  Botanic Ridge, Cranbourne, Cranbourne East, Cr...
# 191       3978                                 Clyde, Clyde North
# 192       3981                                        Koo Wee Rup
#
# [193 rows x 2 columns]

# %%
population_clean_1_df = pd.merge(melb_postcodes_df, population_df, how='inner', on='ABS_SA2_KEY')
population_clean_1_df= population_clean_1_df.dropna(subset=['HOUSE_LOCALITY'])
columns_to_drop = ["RURAL_TOWNSHIP","ABS_SA2_KEY","HOUSE_LOCALITY",
                   "COMMENTS","SUBURB_NAME","SUBURB_POSTCODE_COMMENTS","Geography_Level","Frequency"]
population_clean_1_df = population_clean_1_df.drop(columns_to_drop, axis=1)
population_clean_1_df
# Out:
#                                        MUNICIPALITY         CITY_SHIRE  \
# 0       Inner City municipalities and their suburbs  City of Melbourne
# 1       Inner City municipalities and their suburbs  City of Melbourne
# 2       Inner City municipalities and their suburbs  City of Melbourne
# 3       Inner City municipalities and their suburbs  City of Melbourne
# 4       Inner City municipalities and their suburbs  City of Melbourne
# ...                                             ...                ...
# 484780     Western municipalities and their suburbs    City of Wyndham
# 484781     Western municipalities and their suburbs    City of Wyndham
# 484782     Western municipalities and their suburbs    City of Wyndham
# 484783     Western municipalities and their suburbs    City of Wyndham
# 484784     Western municipalities and their suburbs    City of Wyndham
#
#        SUBURB_GROUP  POST_CODE  SCHOOL_POST_CODE      Gender  \
# 0             Inner       3053            3053.0  3: Persons
# 1             Inner       3053            3053.0  3: Persons
# 2             Inner       3053            3053.0  3: Persons
# 3             Inner       3053            3053.0  3: Persons
# 4             Inner       3053            3053.0  3: Persons
# ...             ...        ...               ...         ...
# 484780        Outer       3024            3024.0  2: Females
# 484781        Outer       3024            3024.0  2: Females
# 484782        Outer       3024            3024.0  2: Females
# 484783        Outer       3024            3024.0  2: Females
# 484784        Outer       3024            3024.0  2: Females
#
#                       Age  Year  Estimated_Resident_Population
# 0           TOT: All ages  2001                           9529
# 1           TOT: All ages  2002                          10022
# 2           TOT: All ages  2003                          10611
# 3           TOT: All ages  2004                          11224
# 4           TOT: All ages  2005                          11924
# ...                   ...   ...                            ...
# 484780  8599: 85 and over  2017                             21
# 484781  8599: 85 and over  2018                             21
# 484782  8599: 85 and over  2019                             18
# 484783  8599: 85 and over  2020                             22
# 484784  8599: 85 and over  2021                             26
#
# [484785 rows x 9 columns]

# %%
population_clean_final_df = pd.merge(population_clean_1_df, postcode_suburbs_df, how='inner', on='POST_CODE')
new_column_names = {
    "SUBURB_NAME": "SUBURB_NAMES",
    }
population_clean_final_df = population_clean_final_df.rename(columns=new_column_names)
population_clean_final_df
# Out:
#                                        MUNICIPALITY         CITY_SHIRE  \
# 0       Inner City municipalities and their suburbs  City of Melbourne
# 1       Inner City municipalities and their suburbs  City of Melbourne
# 2       Inner City municipalities and their suburbs  City of Melbourne
# 3       Inner City municipalities and their suburbs  City of Melbourne
# 4       Inner City municipalities and their suburbs  City of Melbourne
# ...                                             ...                ...
# 484780     Western municipalities and their suburbs    City of Wyndham
# 484781     Western municipalities and their suburbs    City of Wyndham
# 484782     Western municipalities and their suburbs    City of Wyndham
# 484783     Western municipalities and their suburbs    City of Wyndham
# 484784     Western municipalities and their suburbs    City of Wyndham
#
#        SUBURB_GROUP  POST_CODE  SCHOOL_POST_CODE      Gender  \
# 0             Inner       3053            3053.0  3: Persons
# 1             Inner       3053            3053.0  3: Persons
# 2             Inner       3053            3053.0  3: Persons
# 3             Inner       3053            3053.0  3: Persons
# 4             Inner       3053            3053.0  3: Persons
# ...             ...        ...               ...         ...
# 484780        Outer       3024            3024.0  2: Females
# 484781        Outer       3024            3024.0  2: Females
# 484782        Outer       3024            3024.0  2: Females
# 484783        Outer       3024            3024.0  2: Females
# 484784        Outer       3024            3024.0  2: Females
#
#                       Age  Year  Estimated_Resident_Population  \
# 0           TOT: All ages  2001                           9529
# 1           TOT: All ages  2002                          10022
# 2           TOT: All ages  2003                          10611
# 3           TOT: All ages  2004                          11224
# 4           TOT: All ages  2005                          11924
# ...                   ...   ...                            ...
# 484780  8599: 85 and over  2017                             21
# 484781  8599: 85 and over  2018                             21
# 484782  8599: 85 and over  2019                             18
# 484783  8599: 85 and over  2020                             22
# 484784  8599: 85 and over  2021                             26
#
#                                 SUBURB_NAMES
# 0                                    Carlton
# 1                                    Carlton
# 2                                    Carlton
# 3                                    Carlton
# 4                                    Carlton
# ...                                      ...
# 484780  Manor Lakes, Wyndham Vale, Mambourin
# 484781  Manor Lakes, Wyndham Vale, Mambourin
# 484782  Manor Lakes, Wyndham Vale, Mambourin
# 484783  Manor Lakes, Wyndham Vale, Mambourin
# 484784  Manor Lakes, Wyndham Vale, Mambourin
#
# [484785 rows x 10 columns]

# %%
unique_count = population_clean_final_df['POST_CODE'].nunique()

# Display the count of unique strings
print(unique_count)
# Out:
# 193

# %%
# List all the unique strings in a column
unique_strings = population_clean_final_df['Age'].unique()

# Display the unique strings
print(unique_strings)
# Out:
# ['TOT: All ages' 'A04: 0-4' 'A59: 5-9' 'A10: 10-14' 'A15: 15-19'
#  'A20: 20-24' 'A25: 25-29' 'A30: 30-34' 'A35: 35-39' 'A40: 40-44'
#  'A45: 45-49' 'A50: 50-54' 'A55: 55-59' 'A60: 60-64' 'A65: 65-69'
#  'A70: 70-74' 'A75: 75-79' 'A80: 80-84' '8599: 85 and over']

# %%
# Check for NaN values in a column
has_nan = population_clean_final_df['Estimated_Resident_Population'].isna().any()

# Display the result - False (no NaN values in column), True (at least one NaN value in column)
print(has_nan)
# Out:
# False

# %%
population_clean_final_df = population_clean_final_df.drop_duplicates()
# Reset the index and make POST_CODE the new index
population_clean_final_df = population_clean_final_df.set_index('POST_CODE')

# Export cleaned population dataset to a CSV file
population_clean_final_df.to_csv("Cleaned_Data/population_clean_final.csv", index_label="POST_CODE")
population_clean_final_df
# Out:
#                                           MUNICIPALITY         CITY_SHIRE  \
# POST_CODE
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# ...                                                ...                ...
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
#
#           SUBURB_GROUP  SCHOOL_POST_CODE      Gender                Age  Year  \
# POST_CODE
# 3053             Inner            3053.0  3: Persons      TOT: All ages  2001
# 3053             Inner            3053.0  3: Persons      TOT: All ages  2002
# 3053             Inner            3053.0  3: Persons      TOT: All ages  2003
# 3053             Inner            3053.0  3: Persons      TOT: All ages  2004
# 3053             Inner            3053.0  3: Persons      TOT: All ages  2005
# ...                ...               ...         ...                ...   ...
# 3024             Outer            3024.0  2: Females  8599: 85 and over  2017
# 3024             Outer            3024.0  2: Females  8599: 85 and over  2018
# 3024             Outer            3024.0  2: Females  8599: 85 and over  2019
# 3024             Outer            3024.0  2: Females  8599: 85 and over  2020
# 3024             Outer            3024.0  2: Females  8599: 85 and over  2021
#
#            Estimated_Resident_Population                          SUBURB_NAMES
# POST_CODE
# 3053                                9529                               Carlton
# 3053                               10022                               Carlton
# 3053                               10611                               Carlton
# 3053                               11224                               Carlton
# 3053                               11924                               Carlton
# ...                                  ...                                   ...
# 3024                                  21  Manor Lakes, Wyndham Vale, Mambourin
# 3024                                  21  Manor Lakes, Wyndham Vale, Mambourin
# 3024                                  18  Manor Lakes, Wyndham Vale, Mambourin
# 3024                                  22  Manor Lakes, Wyndham Vale, Mambourin
# 3024                                  26  Manor Lakes, Wyndham Vale, Mambourin
#
# [231021 rows x 9 columns]
