# %% [markdown]
# # Merge All Data
# ### Median House Price, Crime, Population, Schools,Hospitals, Police Stations, Supermarkets

# %%
# Import the required libraries
import requests
import json
import pandas as pd
import numpy as np

# %%
#Import house median price Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Cleaned_Data/house_by_postcode_2022.csv"
house_df = pd.read_csv(file_path, encoding="utf-8")
# Rename the column
house_df = house_df.rename(columns={"2022": "Median House Price 2022"})

# Set POST_CODE as the index
house_df.set_index('POST_CODE', inplace=True)

# Reformat the "Median House Price 2022" column
house_df["Median House Price 2022"] = house_df["Median House Price 2022"].apply(lambda x: '{:,.0f}'.format(x))

house_df
# Out:
#                                        MUNICIPALITY          CITY_SHIRE  \
# POST_CODE
# 3104       Eastern municipalities and their suburbs  City of Boroondara
# 3103       Eastern municipalities and their suburbs  City of Boroondara
# 3124       Eastern municipalities and their suburbs  City of Boroondara
# 3122       Eastern municipalities and their suburbs  City of Boroondara
# 3123       Eastern municipalities and their suburbs  City of Boroondara
# ...                                             ...                 ...
# 3337       Western municipalities and their suburbs      City of Melton
# 3335       Western municipalities and their suburbs      City of Melton
# 3030       Western municipalities and their suburbs     City of Wyndham
# 3024       Western municipalities and their suburbs     City of Wyndham
# 3029       Western municipalities and their suburbs     City of Wyndham
#
#           SUBURB_GROUP                                       SUBURB_NAMES  \
# POST_CODE
# 3104               Mid                                       Balwyn North
# 3103               Mid                                   Balwyn, Deepdene
# 3124               Mid                                         Camberwell
# 3122               Mid                                           Hawthorn
# 3123               Mid                                      Hawthorn East
# ...                ...                                                ...
# 3337             Outer                     Kurunjang, Melton, Melton West
# 3335             Outer  Rockbank, Strathtulloh, Taylors Hill, Thornhil...
# 3030             Outer  Derrimut, Point Cook, Sanctuary Lakes, Werribe...
# 3024             Outer               Manor Lakes, Wyndham Vale, Mambourin
# 3029             Outer  Truganina, Weir Views, Hoppers Crossing, Tarne...
#
#           Median House Price 2022
# POST_CODE
# 3104                    2,230,000
# 3103                    2,925,750
# 3124                    2,650,000
# 3122                    2,475,000
# 3123                    2,521,500
# ...                           ...
# 3337                      533,667
# 3335                      690,000
# 3030                      753,800
# 3024                      619,833
# 3029                      626,625
#
# [193 rows x 5 columns]

# %%
# Set the display format for the specified columns
pd.options.display.float_format = "{:,.0f}".format

# Import crime Data
file_path = "Cleaned_Data/crime_by_postcode_offence_division_2023.csv"
crime_df = pd.read_csv(file_path, encoding="utf-8")

# Rename the columns for 2023
crime_df = crime_df.rename(columns={
    "A Crimes against the person": "A Crimes against the person 2023",
    "B Property and deception offences": "B Property and deception offences 2023",
    "C Drug offences": "C Drug offences 2023",
    "D Public order and security offences": "D Public order and security offences 2023",
    "E Justice procedures offences": "E Justice procedures offences 2023",
    "F Other offences": "F Other offences 2023"
})

# Set POST_CODE as the index
crime_df.set_index('POST_CODE', inplace=True)

crime_df = crime_df.drop(['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP','SUBURB_NAMES'], axis=1)
# Display the DataFrame
crime_df
# Out:
#            A Crimes against the person 2023  \
# POST_CODE
# 3003                                    130
# 3011                                    434
# 3012                                    181
# 3013                                     86
# 3015                                     87
# ...                                     ...
# 3975                                    109
# 3976                                    321
# 3977                                   1197
# 3978                                    317
# 3981                                     47
#
#            B Property and deception offences 2023  C Drug offences 2023  \
# POST_CODE
# 3003                                          538                    60
# 3011                                         1402                   100
# 3012                                         1194                    39
# 3013                                          575                    30
# 3015                                          595                    19
# ...                                           ...                   ...
# 3975                                          356                    18
# 3976                                          515                    47
# 3977                                         2603                   181
# 3978                                          927                    28
# 3981                                          116                     4
#
#            D Public order and security offences 2023  \
# POST_CODE
# 3003                                              64
# 3011                                             138
# 3012                                              49
# 3013                                              32
# 3015                                              28
# ...                                              ...
# 3975                                              14
# 3976                                              31
# 3977                                             161
# 3978                                              31
# 3981                                              11
#
#            E Justice procedures offences 2023  F Other offences 2023  \
# POST_CODE
# 3003                                       70                      7
# 3011                                      287                      4
# 3012                                      142                      0
# 3013                                       69                      0
# 3015                                       63                      1
# ...                                       ...                    ...
# 3975                                       71                      0
# 3976                                      229                      3
# 3977                                      762                      1
# 3978                                      197                      0
# 3981                                       20                      0
#
#            Total Crime 2023
# POST_CODE
# 3003                    869
# 3011                   2365
# 3012                   1605
# 3013                    792
# 3015                    793
# ...                     ...
# 3975                    568
# 3976                   1146
# 3977                   4905
# 3978                   1500
# 3981                    198
#
# [193 rows x 7 columns]

# %%
#Import population Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Cleaned_Data/population_by_postcode_2021.csv"
population_df = pd.read_csv(file_path, encoding="utf-8")
# Rename the column
population_df = population_df.rename(columns={"Estimated_Resident_Population": "Estimated_Resident_Population_2021"})
# Set POST_CODE as the index
population_df.set_index('POST_CODE', inplace=True)

population_df = population_df.drop(['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP','SUBURB_NAMES'], axis=1)
population_df
# Out:
#            Estimated_Resident_Population_2021
# POST_CODE
# 3003                                     7619
# 3011                                    17420
# 3012                                    11885
# 3013                                    15653
# 3015                                    18985
# ...                                       ...
# 3975                                    18270
# 3976                                    12861
# 3977                                    21580
# 3978                                    10642
# 3981                                    10148
#
# [193 rows x 1 columns]

# %%
#Import school Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Cleaned_Data/school_count_postcode_2022.csv"
school_df = pd.read_csv(file_path, encoding="utf-8")

# Set POST_CODE as the index
school_df.set_index('POST_CODE', inplace=True)

# Rename the column
school_df = school_df.rename(columns={"School_Count": "School_Count_2022"})
school_df = school_df.drop(['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP','SUBURB_NAMES'], axis=1)
school_df
# Out:
#            School_Count_2022
# POST_CODE
# 3003                       1
# 3011                       6
# 3012                       3
# 3013                       5
# 3015                       6
# ...                      ...
# 3975                       3
# 3976                       6
# 3977                      25
# 3978                      10
# 3981                       4
#
# [193 rows x 1 columns]

# %%
#Import hospital Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Cleaned_Data/hospital_count_by_postcode_2023.csv"
hospital_df = pd.read_csv(file_path, encoding="utf-8")
# Set POST_CODE as the index
hospital_df.set_index('POST_CODE', inplace=True)
hospital_df = hospital_df.rename(columns={"Hospital_Count": "Hospital_Count_2023"})
hospital_df = hospital_df.drop(['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP'], axis=1)
hospital_df
# Out:
#            Hospital_Count_2023
# POST_CODE
# 3011                         1
# 3016                         1
# 3018                         0
# 3021                         1
# 3030                         1
# ...                        ...
# 3910                         1
# 3915                         1
# 3931                         1
# 3939                         1
# 3977                         1
#
# [69 rows x 1 columns]

# %%
#Import police Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Cleaned_Data/police_count_by_postcode_2023.csv"
police_df = pd.read_csv(file_path, encoding="utf-8")
# Set POST_CODE as the index
police_df.set_index('POST_CODE', inplace=True)
police_df = police_df.rename(columns={"Police_Count": "Police_Count_2023"})
police_df = police_df.drop(['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP'], axis=1)
police_df
# Out:
#            Police_Count_2023
# POST_CODE
# 3011                       1
# 3016                       1
# 3018                       1
# 3020                       1
# 3023                       1
# ...                      ...
# 3915                       1
# 3931                       1
# 3936                       1
# 3939                       1
# 3977                       1
#
# [84 rows x 1 columns]

# %%
#Import supermarket Data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

file_path = "Cleaned_Data/supermarket_count_by_postcode_2023.csv"
market_df = pd.read_csv(file_path, encoding="utf-8")
# Set POST_CODE as the index
market_df.set_index('POST_CODE', inplace=True)
market_df = market_df.rename(columns={"Supermarket_Count": "Supermarket_Count_2023"})
market_df = market_df.drop(['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP'], axis=1)

market_df
# Out:
#            Supermarket_Count_2023
# POST_CODE
# 3003                            1
# 3011                            1
# 3012                            1
# 3013                            1
# 3016                            1
# ...                           ...
# 3936                            1
# 3939                            1
# 3975                            1
# 3976                            1
# 3977                            1
#
# [152 rows x 1 columns]

# %%
# Merge the DataFrames
merged_df = house_df.merge(crime_df, on='POST_CODE', how='outer')
merged_df = merged_df.merge(population_df, on='POST_CODE', how='outer')
merged_df = merged_df.merge(school_df, on='POST_CODE', how='outer')
merged_df = merged_df.merge(hospital_df, on='POST_CODE', how='outer')
merged_df = merged_df.merge(police_df, on='POST_CODE', how='outer')
merged_df = merged_df.merge(market_df, on='POST_CODE', how='outer')

# Specify the order of columns
column_order = ['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP'] + [col for col in merged_df.columns if col not in ['MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP']]

# Reorder the columns
merged_df = merged_df[column_order]
merged_df = merged_df.fillna(0)
# Display the merged DataFrame
# Export cleaned population dataset to a CSV file
merged_df.to_csv("Cleaned_Data/merged_all_data.csv", index_label="POST_CODE")
merged_df
# Out:
#                                        MUNICIPALITY          CITY_SHIRE  \
# POST_CODE
# 3104       Eastern municipalities and their suburbs  City of Boroondara
# 3103       Eastern municipalities and their suburbs  City of Boroondara
# 3124       Eastern municipalities and their suburbs  City of Boroondara
# 3122       Eastern municipalities and their suburbs  City of Boroondara
# 3123       Eastern municipalities and their suburbs  City of Boroondara
# ...                                             ...                 ...
# 3337       Western municipalities and their suburbs      City of Melton
# 3335       Western municipalities and their suburbs      City of Melton
# 3030       Western municipalities and their suburbs     City of Wyndham
# 3024       Western municipalities and their suburbs     City of Wyndham
# 3029       Western municipalities and their suburbs     City of Wyndham
#
#           SUBURB_GROUP                                       SUBURB_NAMES  \
# POST_CODE
# 3104               Mid                                       Balwyn North
# 3103               Mid                                   Balwyn, Deepdene
# 3124               Mid                                         Camberwell
# 3122               Mid                                           Hawthorn
# 3123               Mid                                      Hawthorn East
# ...                ...                                                ...
# 3337             Outer                     Kurunjang, Melton, Melton West
# 3335             Outer  Rockbank, Strathtulloh, Taylors Hill, Thornhil...
# 3030             Outer  Derrimut, Point Cook, Sanctuary Lakes, Werribe...
# 3024             Outer               Manor Lakes, Wyndham Vale, Mambourin
# 3029             Outer  Truganina, Weir Views, Hoppers Crossing, Tarne...
#
#           Median House Price 2022  A Crimes against the person 2023  \
# POST_CODE
# 3104                    2,230,000                                67
# 3103                    2,925,750                                67
# 3124                    2,650,000                                92
# 3122                    2,475,000                               128
# 3123                    2,521,500                                79
# ...                           ...                               ...
# 3337                      533,667                               681
# 3335                      690,000                                81
# 3030                      753,800                              1241
# 3024                      619,833                               385
# 3029                      626,625                              1146
#
#            B Property and deception offences 2023  C Drug offences 2023  \
# POST_CODE
# 3104                                          400                    10
# 3103                                          321                     6
# 3124                                          634                    11
# 3122                                          783                    14
# 3123                                          416                     7
# ...                                           ...                   ...
# 3337                                         1374                   102
# 3335                                          549                    17
# 3030                                         3145                   228
# 3024                                          912                    52
# 3029                                         3622                   138
#
#            D Public order and security offences 2023  \
# POST_CODE
# 3104                                              11
# 3103                                              14
# 3124                                              21
# 3122                                              14
# 3123                                              14
# ...                                              ...
# 3337                                             132
# 3335                                              14
# 3030                                             256
# 3024                                              53
# 3029                                             204
#
#            E Justice procedures offences 2023  F Other offences 2023  \
# POST_CODE
# 3104                                       30                      0
# 3103                                       27                      2
# 3124                                       74                      2
# 3122                                       58                      2
# 3123                                       36                      1
# ...                                       ...                    ...
# 3337                                      469                      7
# 3335                                       42                      1
# 3030                                     1016                      8
# 3024                                      196                      2
# 3029                                      578                     13
#
#            Total Crime 2023  Estimated_Resident_Population_2021  \
# POST_CODE
# 3104                    518                               21411
# 3103                    437                               16332
# 3124                    834                               21512
# 3122                    999                               10037
# 3123                    553                               15898
# ...                     ...                                 ...
# 3337                   2765                               21502
# 3335                    704                               17836
# 3030                   5894                                8751
# 3024                   1600                               10781
# 3029                   5701                               18663
#
#            School_Count_2022  Hospital_Count_2023  Police_Count_2023  \
# POST_CODE
# 3104                       7                    0                  0
# 3103                       5                    0                  0
# 3124                       4                    0                  1
# 3122                       8                    1                  0
# 3123                       5                    0                  0
# ...                      ...                  ...                ...
# 3337                      15                    1                  1
# 3335                       1                    0                  0
# 3030                      25                    1                  1
# 3024                       5                    0                  0
# 3029                      26                    0                  1
#
#            Supermarket_Count_2023
# POST_CODE
# 3104                            1
# 3103                            1
# 3124                            0
# 3122                            1
# 3123                            1
# ...                           ...
# 3337                            1
# 3335                            0
# 3030                            1
# 3024                            1
# 3029                            1
#
# [193 rows x 17 columns]
