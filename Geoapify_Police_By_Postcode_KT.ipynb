# %% [markdown]
# # Geoapify Melbourne Locations
# ## Police Stations

# %%
# Dependencies
import requests
import json
import pandas as pd

# Import the API key
from config import geoapify_key

# %%
# Set the parameters for the type of place - police stations
categories = "service.police"

# Set the parameters for the type of search of Melbourne (incl all Municipalities)
filters = "place:51397cf9ca8e286240593190f739f8ec42c0f00101f9016cca400000000000c002089203094d656c626f75726e65"
limit = 500

# Set up a parameters dictionary
params = {
    "categories": categories,
    "limit": limit,
    "filter": filters,
    "apiKey": geoapify_key
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# Run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://api.geoapify.com/v2/places?categories=service.police&limit=500&filter=place%3A51397cf9ca8e286240593190f739f8ec42c0f00101f9016cca400000000000c002089203094d656c626f75726e65&apiKey=79372d4c67c34669935344d46743808f

# %%
# Convert response to JSON
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.22694819483766,
#                     -37.81310875615223
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Ringwood Police Complex",
#                 "address_line2": "31 Ringwood Street, Ringwood VIC 3134, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 31,
#                         "addr:postcode": 3134,
#                         "addr:state": "VIC",
#                         "addr:street": "Ringwood Street",
#                         "addr:suburb": "Ringwood",
#                         "amenity": "police",
#                         "building": "yes",
#                         "email": "ringwood.uni@police.vic.gov.au",
#                         "fax": "+61 3 9871 3024",
#                         "name": "Ringwood Police Complex",
#                         "opening_hours": "24/7",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "operator:wikipedia": "en:Victoria Police",
#                         "osm_id": 328927124,
#                         "osm_type": "w",
#                         "phone": "+61 3 9871 3000",
#                         "ref": 212459,
#                         "website": "https://www.police.vic.gov.au/",
#                         "wheelchair": "yes",
#                         "wikidata": "Q28927200"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Ringwood Police Complex, 31 Ringwood Street, Ringwood VIC 3134, Australia",
#                 "housenumber": "31",
#                 "lat": -37.81308505,
#                 "lon": 145.22695863866056,
#                 "municipality": "City of Maroondah",
#                 "name": "Ringwood Police Complex",
#                 "place_id": "51d956dc284327624059eee19df213e842c0f00102f90194079b130000000092031752696e67776f6f6420506f6c69636520436f6d706c6578",
#                 "postcode": "3134",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Ringwood Street",
#                 "suburb": "Ringwood"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.07067809999998,
#                     -37.75753530051839
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Heidelberg Police Station",
#                 "address_line2": "11 Jika Street, Heidelberg VIC 3084, Australia",
#                 "categories": [
#                     "service",
#                     "service.police",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Heidelberg",
#                         "addr:country": "AU",
#                         "addr:housenumber": 11,
#                         "addr:postcode": 3084,
#                         "addr:state": "VIC",
#                         "addr:street": "Jika Street",
#                         "amenity": "police",
#                         "fax": "+61 3 9450 8188",
#                         "level": 0,
#                         "name": "Heidelberg Police Station",
#                         "opening_hours": "24/7",
#                         "operator": "Victoria Police",
#                         "osm_id": 1973362838,
#                         "osm_type": "n",
#                         "phone": "+61 3 9450 8000",
#                         "website": "https://www.police.vic.gov.au/content.asp?Document_ID=634",
#                         "wheelchair": "yes",
#                         "wikidata": "Q28927094"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Heidelberg Police Station, 11 Jika Street, Heidelberg VIC 3084, Australia",
#                 "housenumber": "11",
#                 "lat": -37.7575353,
#                 "lon": 145.0706781,
#                 "municipality": "City of Banyule",
#                 "name": "Heidelberg Police Station",
#                 "place_id": "516301b8fe422262405961a5aeeaf6e042c0f00103f90196209f750000000092031948656964656c6265726720506f6c6963652053746174696f6e",
#                 "postcode": "3084",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Jika Street",
#                 "suburb": "Heidelberg"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.36491925287302,
#                     -37.856166573147576
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Olinda Police Station",
#                 "address_line2": "549 Mount Dandenong Tourist Road, Olinda VIC 3788, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 549,
#                         "addr:street": "Mount Dandenong Tourist Road",
#                         "amenity": "police",
#                         "building": "yes",
#                         "building:levels": 1,
#                         "email": "olinda.uni@police.vic.gov.au",
#                         "fax": "+61 3 9751 1424",
#                         "layer": 1,
#                         "name": "Olinda Police Station",
#                         "osm_id": 49826174,
#                         "osm_type": "w",
#                         "phone": "+61 3 9751 1241",
#                         "website": "https://www.police.vic.gov.au",
#                         "wikidata": "Q28927174"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Olinda Police Station, 549 Mount Dandenong Tourist Road, Olinda VIC 3788, Australia",
#                 "housenumber": "549",
#                 "lat": -37.856188599999996,
#                 "lon": 145.36493735394095,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "Olinda Police Station",
#                 "place_id": "51a718246bad2b62405972ccc3dd96ed42c0f00102f9017e49f802000000009203154f6c696e646120506f6c6963652053746174696f6e",
#                 "postcode": "3788",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Mount Dandenong Tourist Road",
#                 "suburb": "Olinda"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.1578704,
#                     -37.7882544005252
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Doncaster Police Station",
#                 "address_line2": "979 Doncaster Road, Doncaster East VIC 3109, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 979,
#                         "addr:postcode": 3109,
#                         "addr:state": "VIC",
#                         "addr:street": "Doncaster Road",
#                         "addr:suburb": "Doncaster East",
#                         "amenity": "police",
#                         "is_in": "East Doncaster,Victoria,Australia",
#                         "name": "Doncaster Police Station",
#                         "opening_hours": "24/7",
#                         "osm_id": 89090066,
#                         "osm_type": "n",
#                         "phone": "+61388413999",
#                         "postal_code": 3109,
#                         "wikidata": "Q28927045"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Doncaster Police Station, 979 Doncaster Road, Doncaster East VIC 3109, Australia",
#                 "housenumber": "979",
#                 "lat": -37.7882544,
#                 "lon": 145.1578704,
#                 "municipality": "City of Manningham",
#                 "name": "Doncaster Police Station",
#                 "place_id": "5135a039460d2562405987972b85e5e442c0f00103f90112684f0500000000920318446f6e63617374657220506f6c6963652053746174696f6e",
#                 "postcode": "3109",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Doncaster Road",
#                 "suburb": "Doncaster East"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.92433054200157,
#                     -37.764617571370465
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Moonee Ponds Police Station",
#                 "address_line2": "766 Mount Alexander Road, Moonee Ponds VIC 3039, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 766,
#                         "addr:postcode": 3039,
#                         "addr:state": "VIC",
#                         "addr:street": "Mount Alexander Road",
#                         "addr:suburb": "Moonee Ponds",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Moonee Ponds Police Station",
#                         "opening_hours": "24/7",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "osm_id": 93175179,
#                         "osm_type": "w",
#                         "vic_police:LGA": "Moonee Valley",
#                         "vic_police:PSA": "Moonee Valley",
#                         "vic_police:PSA_hq": "Moonee Ponds",
#                         "vic_police:address": "766 Mt Alexander Road, Moonee Ponds Vic 3039",
#                         "vic_police:division": 4,
#                         "vic_police:division_hq": "Fawkner",
#                         "vic_police:fire_ban_region": "Central",
#                         "vic_police:postcodes": "3040, 3041, 3039, 3042",
#                         "vic_police:region": "North West Metro",
#                         "website": "https://www.police.vic.gov.au/content.asp?Document_ID=558",
#                         "wikidata": "Q28927144"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Moonee Ponds Police Station, 766 Mount Alexander Road, Moonee Ponds VIC 3039, Australia",
#                 "housenumber": "766",
#                 "lat": -37.764619499999995,
#                 "lon": 144.92431942316557,
#                 "municipality": "City of Moonee Valley",
#                 "name": "Moonee Ponds Police Station",
#                 "place_id": "51e712a51d941d624059d67d13fddee142c0f00102f9018bbd8d050000000092031b4d6f6f6e656520506f6e647320506f6c6963652053746174696f6e",
#                 "postcode": "3039",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Mount Alexander Road",
#                 "suburb": "Moonee Ponds"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.35469764399127,
#                     -37.907832022887874
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Belgrave Police Station",
#                 "address_line2": "2 Ena Road, Belgrave VIC 3160, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 2,
#                         "addr:street": "Ena Road",
#                         "amenity": "police",
#                         "building": "yes",
#                         "email": "BELGRAVE.UNI@police.vic.gov.au",
#                         "fax": "+61 3 9754 6833",
#                         "name": "Belgrave Police Station",
#                         "osm_id": 102927114,
#                         "osm_type": "w",
#                         "phone": "+61 3 9754 6677",
#                         "website": "https://www.police.vic.gov.au",
#                         "wikidata": "Q28926993"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Belgrave Police Station, 2 Ena Road, Belgrave VIC 3160, Australia",
#                 "housenumber": "2",
#                 "lat": -37.9077918,
#                 "lon": 145.35471443394584,
#                 "municipality": "Shire of Yarra Ranges",
#                 "name": "Belgrave Police Station",
#                 "place_id": "51259ddfae592b6240595048f8d633f442c0f00102f9010a8b22060000000092031742656c677261766520506f6c6963652053746174696f6e",
#                 "postcode": "3160",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Ena Road",
#                 "suburb": "Belgrave"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.9791784103886,
#                     -37.802217269428894
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Fitzroy Police Station",
#                 "address_line2": "13 Condell Street, Fitzroy VIC 3065, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Fitzroy",
#                         "addr:housenumber": 13,
#                         "addr:postcode": 3065,
#                         "addr:street": "Condell Street",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Fitzroy Police Station",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "operator:wikipedia": "en:Victoria Police",
#                         "osm_id": 188284426,
#                         "osm_type": "w",
#                         "phone": "+61 3 99346400",
#                         "website": "https://www.police.vic.gov.au/",
#                         "wikidata": "Q28927070"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Fitzroy Police Station, 13 Condell Street, Fitzroy VIC 3065, Australia",
#                 "housenumber": "13",
#                 "lat": -37.802217299999995,
#                 "lon": 144.97917842698604,
#                 "municipality": "City of Yarra",
#                 "name": "Fitzroy Police Station",
#                 "place_id": "513032f66d551f624059e43d340eafe642c0f00102f9010afe380b000000009203164669747a726f7920506f6c6963652053746174696f6e",
#                 "postcode": "3065",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Condell Street",
#                 "suburb": "Fitzroy"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.90123873646291,
#                     -37.803850139867926
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Footscray Police Station",
#                 "address_line2": "66 Hyde Street, Footscray VIC 3011, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Footscray",
#                         "addr:housenumber": 66,
#                         "addr:postcode": 3011,
#                         "addr:state": "VIC",
#                         "addr:street": "Hyde Street",
#                         "addr:suburb": "Footscray",
#                         "amenity": "police",
#                         "building": "yes",
#                         "height": 8,
#                         "name": "Footscray Police Station",
#                         "operator": "Victoria Police",
#                         "osm_id": 209529818,
#                         "osm_type": "w",
#                         "phone": "+61 3 8398 9800",
#                         "website": "https://www.police.vic.gov.au/",
#                         "wikidata": "Q28927072"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Footscray Police Station, 66 Hyde Street, Footscray VIC 3011, Australia",
#                 "housenumber": "66",
#                 "lat": -37.80392655,
#                 "lon": 144.90119372359192,
#                 "municipality": "City of Maribyrnong",
#                 "name": "Footscray Police Station",
#                 "place_id": "51e45f9ef2d61c62405913cfb68fe4e642c0f00102f901da2b7d0c00000000920318466f6f74736372617920506f6c6963652053746174696f6e",
#                 "postcode": "3011",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Hyde Street",
#                 "suburb": "Footscray"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.77133096461912,
#                     -37.86319892979907
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Laverton Police Station",
#                 "address_line2": "1 Maher Road, Laverton VIC 3028, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Laverton",
#                         "addr:housenumber": 1,
#                         "addr:postcode": 3028,
#                         "addr:street": "Maher Road",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Laverton Police Station",
#                         "operator": "Victoria Police",
#                         "osm_id": 240627192,
#                         "osm_type": "w",
#                         "phone": "+61 3 93692122",
#                         "website": "https://www.police.vic.gov.au/",
#                         "wikidata": "Q28927116"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Laverton Police Station, 1 Maher Road, Laverton VIC 3028, Australia",
#                 "housenumber": "1",
#                 "lat": -37.86323135,
#                 "lon": 144.77133300474327,
#                 "municipality": "City of Hobsons Bay",
#                 "name": "Laverton Police Station",
#                 "place_id": "51cd6d46beae18624059f0b6724d7dee42c0f00102f901f8ad570e000000009203174c61766572746f6e20506f6c6963652053746174696f6e",
#                 "postcode": "3028",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Maher Road",
#                 "suburb": "Laverton"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.99969819999998,
#                     -37.817509550531646
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Richmond Police Station",
#                 "address_line2": "217 Church Street, Richmond VIC 3121, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Richmond",
#                         "addr:housenumber": 217,
#                         "addr:postcode": 3121,
#                         "addr:street": "Church Street",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Richmond Police Station",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "operator:wikipedia": "en:Victoria Police",
#                         "osm_id": 248744975,
#                         "osm_type": "w",
#                         "phone": "+61 3 84203600",
#                         "website": "https://www.police.vic.gov.au/",
#                         "wikidata": "Q28927196"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Richmond Police Station, 217 Church Street, Richmond VIC 3121, Australia",
#                 "housenumber": "217",
#                 "lat": -37.81750955,
#                 "lon": 144.9996982,
#                 "municipality": "City of Yarra",
#                 "name": "Richmond Police Station",
#                 "place_id": "51d75b1487fd1f624059bdd92727a4e842c0f00102f9010f8cd30e00000000920317526963686d6f6e6420506f6c6963652053746174696f6e",
#                 "postcode": "3121",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Church Street",
#                 "suburb": "Richmond"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.93213199797242,
#                     -37.78532064302396
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Flemington Police Station",
#                 "address_line2": "30 Wellington Street, Flemington VIC 3031, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Flemington",
#                         "addr:housenumber": 30,
#                         "addr:postcode": 3031,
#                         "addr:street": "Wellington Street",
#                         "amenity": "police",
#                         "building": "yes",
#                         "building:levels": 2,
#                         "name": "Flemington Police Station",
#                         "operator": "Victoria Police",
#                         "osm_id": 381863406,
#                         "osm_type": "w",
#                         "phone": "+61 3 93716100",
#                         "website": "http://police.vic.gov.au",
#                         "wheelchair": "yes",
#                         "wikidata": "Q28927071"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact",
#                     "details.facilities",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Newmarket",
#                 "formatted": "Flemington Police Station, 30 Wellington Street, Flemington VIC 3031, Australia",
#                 "housenumber": "30",
#                 "lat": -37.7853611,
#                 "lon": 144.93219393488374,
#                 "municipality": "City of Moonee Valley",
#                 "name": "Flemington Police Station",
#                 "place_id": "5118db7b06d41d624059af54076385e442c0f00102f901eec5c21600000000920319466c656d696e67746f6e20506f6c6963652053746174696f6e",
#                 "postcode": "3031",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Wellington Street",
#                 "suburb": "Flemington"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.90643175719387,
#                     -37.863264509916995
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Williamstown Police Station",
#                 "address_line2": "100 Nelson Place, Williamstown VIC 3016, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Williamstown",
#                         "addr:housenumber": 100,
#                         "addr:postcode": 3016,
#                         "addr:street": "Nelson Place",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Williamstown Police Station",
#                         "operator": "Victoria Police",
#                         "osm_id": 510664520,
#                         "osm_type": "w",
#                         "phone": "+61 3 9393 9555",
#                         "website": "https://www.police.vic.gov.au/content.asp?Document_ID=611",
#                         "wikidata": "Q28927258"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Williamstown Police Station, 100 Nelson Place, Williamstown VIC 3016, Australia",
#                 "housenumber": "100",
#                 "lat": -37.86331455,
#                 "lon": 144.90638117187547,
#                 "municipality": "City of Hobsons Bay",
#                 "name": "Williamstown Police Station",
#                 "place_id": "5183262c7d011d6240590bf292737fee42c0f00102f901481f701e0000000092031b57696c6c69616d73746f776e20506f6c6963652053746174696f6e",
#                 "postcode": "3016",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Nelson Place",
#                 "suburb": "Williamstown"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.2171922,
#                     -37.99017650056935
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Dandenong Police Station",
#                 "address_line2": "50 Langhorne Street, Dandenong VIC 3175, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Dandenong",
#                         "addr:housenumber": 50,
#                         "addr:postcode": 3175,
#                         "addr:street": "Langhorne Street",
#                         "amenity": "police",
#                         "building": "yes",
#                         "fax": "+61 3 9767 7419",
#                         "is_in:country": "Australia",
#                         "name": "Dandenong Police Station",
#                         "operator": "Victoria Police",
#                         "osm_id": 597124620,
#                         "osm_type": "n",
#                         "phone": "+61 3 9767 7444",
#                         "website": "https://www.police.vic.gov.au/content.asp?Document_ID=598",
#                         "wheelchair": "yes",
#                         "wikidata": "Q28927041"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Dandenong Police Station, 50 Langhorne Street, Dandenong VIC 3175, Australia",
#                 "housenumber": "50",
#                 "lat": -37.9901765,
#                 "lon": 145.2171922,
#                 "municipality": "City of Greater Dandenong",
#                 "name": "Dandenong Police Station",
#                 "place_id": "51487e0e3df326624059469b831abefe42c0f00103f9010c6697230000000092031844616e64656e6f6e6720506f6c6963652053746174696f6e",
#                 "postcode": "3175",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Langhorne Street",
#                 "suburb": "Dandenong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.9906544,
#                     -37.867868300542725
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "St Kilda Police Station",
#                 "address_line2": "92 Chapel Street, St Kilda VIC 3182, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 92,
#                         "addr:street": "Chapel Street",
#                         "amenity": "police",
#                         "name": "St Kilda Police Station",
#                         "osm_id": 597124783,
#                         "osm_type": "n",
#                         "phone": "+61 3 95362666",
#                         "website": "https://www.police.vic.gov.au/",
#                         "wikidata": "Q28927212"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "St Kilda Police Station, 92 Chapel Street, St Kilda VIC 3182, Australia",
#                 "housenumber": "92",
#                 "lat": -37.8678683,
#                 "lon": 144.9906544,
#                 "municipality": "City of Port Phillip",
#                 "name": "St Kilda Police Station",
#                 "place_id": "516f34db70b31f6240597608f84e16ef42c0f00103f901af669723000000009203175374204b696c646120506f6c6963652053746174696f6e",
#                 "postcode": "3182",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Chapel Street",
#                 "suburb": "St Kilda"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.2785836,
#                     -37.799029000527554
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Croydon Police Station",
#                 "address_line2": "171-175 Mount Dandenong Road, Croydon VIC 3136, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Croydon",
#                         "addr:housenumber": "171-175",
#                         "addr:postcode": 3136,
#                         "addr:state": "VIC",
#                         "addr:street": "Mount Dandenong Road",
#                         "addr:suburb": "Croydon",
#                         "amenity": "police",
#                         "name": "Croydon Police Station",
#                         "opening_hours": "24/7",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "operator:wikipedia": "en:Victoria Police",
#                         "osm_id": 597124830,
#                         "osm_type": "n",
#                         "website": "https://www.police.vic.gov.au/",
#                         "wikidata": "Q28927039"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Croydon Police Station, 171-175 Mount Dandenong Road, Croydon VIC 3136, Australia",
#                 "housenumber": "171-175",
#                 "lat": -37.799029,
#                 "lon": 145.2785836,
#                 "municipality": "City of Maroondah",
#                 "name": "Croydon Police Station",
#                 "place_id": "5176662728ea2862405924e9109546e642c0f00103f901de6697230000000092031643726f79646f6e20506f6c6963652053746174696f6e",
#                 "postcode": "3136",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Mount Dandenong Road",
#                 "suburb": "Croydon"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.0592856786756,
#                     -37.8331657604302
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Camberwell Police Station",
#                 "address_line2": "317 Camberwell Road, Camberwell VIC 3124, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 317,
#                         "addr:postcode": 3124,
#                         "addr:state": "VIC",
#                         "addr:street": "Camberwell Road",
#                         "addr:suburb": "Camberwell",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Camberwell Police Station",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "operator:wikipedia": "en:Victoria Police",
#                         "osm_id": 682609637,
#                         "osm_type": "w",
#                         "phone": "+61 3 9882 0688",
#                         "website": "https://www.police.vic.gov.au/homepage",
#                         "wikidata": "Q28927018"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Camberwell Police Station, 317 Camberwell Road, Camberwell VIC 3124, Australia",
#                 "housenumber": "317",
#                 "lat": -37.83314795,
#                 "lon": 145.05931276796417,
#                 "municipality": "City of Boroondara",
#                 "name": "Camberwell Police Station",
#                 "place_id": "510d6114abe521624059eb98f62ca5ea42c0f00102f901e5cbaf280000000092031943616d62657277656c6c20506f6c6963652053746174696f6e",
#                 "postcode": "3124",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Camberwell Road",
#                 "suburb": "Camberwell"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.68147309805036,
#                     -37.89436774385139
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Werribee Police Station",
#                 "address_line2": "134 Princes Highway, Werribee VIC 3030, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Werribee",
#                         "addr:housenumber": 134,
#                         "addr:postcode": 3030,
#                         "addr:state": "VIC",
#                         "addr:street": "Princes Highway",
#                         "addr:suburb": "Werribee",
#                         "amenity": "police",
#                         "name": "Werribee Police Station",
#                         "opening_hours": "24/7",
#                         "operator": "Victoria Police",
#                         "operator:wikidata": "Q1406658",
#                         "operator:wikipedia": "en:Victoria Police",
#                         "osm_id": 917281084,
#                         "osm_type": "w",
#                         "phone": "+61 3 97429444",
#                         "website": "https://www.police.vic.gov.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "formatted": "Werribee Police Station, 134 Princes Highway, Werribee VIC 3030, Australia",
#                 "housenumber": "134",
#                 "lat": -37.893859250000006,
#                 "lon": 144.68158580173005,
#                 "municipality": "City of Wyndham",
#                 "name": "Werribee Police Station",
#                 "place_id": "515da7aba0ce15624059323869a47af242c0f00102f9013c99ac3600000000920317576572726962656520506f6c6963652053746174696f6e",
#                 "postcode": "3030",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Princes Highway",
#                 "suburb": "Werribee"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.96319812545337,
#                     -37.76282930747213
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Brunswick Police Station",
#                 "address_line2": "630 Sydney Road, Brunswick VIC 3056, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Brunswick",
#                         "addr:housenumber": 630,
#                         "addr:postcode": 3056,
#                         "addr:street": "Sydney Road",
#                         "amenity": "police",
#                         "building": "yes",
#                         "name": "Brunswick Police Station",
# ...
#                 "state_code": "VIC",
#                 "street": "Eramosa Road West",
#                 "suburb": "Somerville"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.1929861473903,
#                     -37.640023661377796
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Parker Row",
#                 "address_line2": "Hurstbridge VIC 3099, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "building": "yes",
#                         "osm_id": 161959188,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Parker Row, Hurstbridge VIC 3099, Australia",
#                 "lat": -37.640072200000006,
#                 "lon": 145.1929432131433,
#                 "municipality": "Shire of Nillumbik",
#                 "place_id": "51eaf348f12c2662405954249b4becd142c0f00102f901144da70900000000",
#                 "postcode": "3099",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Parker Row",
#                 "suburb": "Hurstbridge"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.21717603827562,
#                     -37.99024521927579
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Langhorne Street",
#                 "address_line2": "Dandenong VIC 3177, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "building": "yes",
#                         "height": 8,
#                         "osm_id": 201711232,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.building"
#                 ],
#                 "formatted": "Langhorne Street, Dandenong VIC 3177, Australia",
#                 "lat": -37.99029055,
#                 "lon": 145.2172189774671,
#                 "municipality": "City of Greater Dandenong",
#                 "place_id": "51ccbb291bf326624059aae7f75ac0fe42c0f00102f90180de050c00000000",
#                 "postcode": "3177",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Langhorne Street",
#                 "suburb": "Dandenong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.85961624225524,
#                     -37.75569798084897
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Military Road",
#                 "address_line2": "Avondale Heights VIC 3034, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "building": "yes",
#                         "osm_id": 262495413,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Military Road, Avondale Heights VIC 3034, Australia",
#                 "lat": -37.75569795,
#                 "lon": 144.85961624255924,
#                 "municipality": "City of Moonee Valley",
#                 "place_id": "5118f3ebf9811b62405925b320b6bae042c0f00102f901b55ca50f00000000",
#                 "postcode": "3034",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Military Road",
#                 "suburb": "Avondale Heights"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.02756364600683,
#                     -37.74038610739986
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Murray Road",
#                 "address_line2": "Preston VIC 3072, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "building": "yes",
#                         "osm_id": 364900796,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Murray Road, Preston VIC 3072, Australia",
#                 "lat": -37.74038065,
#                 "lon": 145.02756518837657,
#                 "municipality": "City of Darebin",
#                 "place_id": "510dc527cde120624059fad8d2f8c4de42c0f00102f901bcf1bf1500000000",
#                 "postcode": "3072",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Murray Road",
#                 "suburb": "Preston"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.15526890739383,
#                     -38.221213500600264
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coolart Road",
#                 "address_line2": "Somerville VIC 3912, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "building": "yes",
#                         "osm_id": 638660029,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Coolart Road, Somerville VIC 3912, Australia",
#                 "lat": -38.22121685,
#                 "lon": 145.15534728066663,
#                 "municipality": "Shire of Mornington Peninsula",
#                 "place_id": "51f3ea7ff6f724624059834157b9501c43c0f00102f901bd2d112600000000",
#                 "postcode": "3912",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Coolart Road",
#                 "suburb": "Somerville"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.0053364491987,
#                     -37.716612032267165
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Edwardes Street",
#                 "address_line2": "Reservoir VIC 3073, Australia",
#                 "categories": [
#                     "building",
#                     "building.facility",
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "building": "yes",
#                         "osm_id": 713212845,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Edwardes Street, Reservoir VIC 3073, Australia",
#                 "lat": -37.7166247,
#                 "lon": 145.00533251519767,
#                 "municipality": "City of Darebin",
#                 "place_id": "51205958b72b20624059f8406df1b9db42c0f00102f901adc3822a00000000",
#                 "postcode": "3073",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Edwardes Street",
#                 "suburb": "Reservoir"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     145.17159462759358,
#                     -37.84575063693912
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Springvale Road",
#                 "address_line2": "Vermont South VIC 3151, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "osm_id": 722668356,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Springvale Road, Vermont South VIC 3151, Australia",
#                 "lat": -37.845766600000005,
#                 "lon": 145.17161264209756,
#                 "municipality": "City of Whitehorse",
#                 "place_id": "51e13504b47d25624059c31c8f8e41ec42c0f00102f901440b132b00000000",
#                 "postcode": "3151",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Springvale Road",
#                 "suburb": "Vermont South"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.85064200737915,
#                     -37.67650771124826
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Service Road",
#                 "address_line2": "Melbourne Airport VIC 3045, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "osm_id": 744521678,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Service Road, Melbourne Airport VIC 3045, Australia",
#                 "lat": -37.67648165,
#                 "lon": 144.85064019822116,
#                 "municipality": "City of Hume",
#                 "place_id": "5183499675381b624059cca6ffcd97d642c0f00102f901ce7f602c00000000",
#                 "postcode": "3045",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Service Road",
#                 "suburb": "Melbourne Airport"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     144.7705827,
#                     -37.77693740052269
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Railway Parade",
#                 "address_line2": "Deer Park VIC 3023, Australia",
#                 "categories": [
#                     "service",
#                     "service.police"
#                 ],
#                 "city": "Melbourne",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "police",
#                         "osm_id": 4060933063,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "formatted": "Railway Parade, Deer Park VIC 3023, Australia",
#                 "lat": -37.7769374,
#                 "lon": 144.7705827,
#                 "municipality": "City of Brimbank",
#                 "place_id": "51a1eb0c9da81862405961244baf72e342c0f00103f901c7eb0cf200000000",
#                 "postcode": "3023",
#                 "state": "Victoria",
#                 "state_code": "VIC",
#                 "street": "Railway Parade",
#                 "suburb": "Deer Park"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Create an empty list to store police data
police_data = []

# Check if "features" key exists in the JSON response
if "features" in places_data:
    # Loop through all the police
    for feature in places_data["features"]:
        # Retrieve the desired information for each police
        properties = feature.get("properties", {})
        name = properties.get("name", None)
        address = properties.get("address_line2", None)
        municipality = properties.get("municipality", None)
        suburb = properties.get("suburb", None)
        postcode = properties.get("postcode", None)
        latitude = properties.get("lat", None)
        longitude = properties.get("lon", None)

        # Append the police data to the list
        police_data.append({
            "NAME": name,
            "Address": address,
            "Municipality": municipality,
            "Suburb": suburb,
            "POST_CODE": postcode,
            "Latitude":latitude,
            "Longitude":longitude
        })

    # Create a DataFrame from the police data
    police_df = pd.DataFrame(police_data)

else:
    print("No police data found.")

# Replace blank values in the "NAME" column with corresponding "Address" values
police_df["NAME"].fillna(police_df["Address"], inplace=True)

#drop rows with POST_CODE missing
police_df = police_df.dropna(subset=["POST_CODE"])


# Sort the DataFrame by the "POST_CODE" column
police_df = police_df.sort_values(by='POST_CODE')

# Reset the index and make POST_CODE the new index
police_df = police_df.set_index('POST_CODE')
police_df
# Out:
#                                            NAME  \
# POST_CODE
# 3000                   Melbourne Custody Centre
# 3000       Flinders Street Station Police Booth
# 3000              Spencer Street Police Complex
# 3000              Melbourne West Police Station
# 3000                     Melbourne Prosecutions
# ...                                         ...
# 3936                     Dromana Police Station
# 3939                     Rosebud Police Station
# 3941                                        Rye
# 3943                                   Sorrento
# 3977                                 Cranbourne
#
#                                                      Address  \
# POST_CODE
# 3000           William Street, Melbourne VIC 3000, Australia
# 3000       207-361 Flinders Street, Melbourne VIC 3000, A...
# 3000       263-313 Spencer Street, Docklands VIC 3000, Au...
# 3000       313 Spencer Street, Docklands VIC 3000, Australia
# 3000       456 Lonsdale Street, Melbourne VIC 3000, Austr...
# ...                                                      ...
# 3936          Point Nepean Road, Dromana VIC 3936, Australia
# 3939              95 Boneo Road, Rosebud VIC 3939, Australia
# 3941                                 Rye VIC 3941, Australia
# 3943                            Sorrento VIC 3943, Australia
# 3977                          Cranbourne VIC 3977, Australia
#
#                             Municipality      Suburb   Latitude   Longitude
# POST_CODE
# 3000                   City of Melbourne   Melbourne -37.813400  144.957000
# 3000                   City of Melbourne   Melbourne -37.817967  144.967320
# 3000                   City of Melbourne   Docklands -37.813757  144.950959
# 3000                   City of Melbourne   Docklands -37.813527  144.951203
# 3000                   City of Melbourne   Melbourne -37.813200  144.958000
# ...                                  ...         ...        ...         ...
# 3936       Shire of Mornington Peninsula     Dromana -38.334746  144.961068
# 3939       Shire of Mornington Peninsula     Rosebud -38.369808  144.889915
# 3941       Shire of Mornington Peninsula         Rye -38.370600  144.819000
# 3943       Shire of Mornington Peninsula    Sorrento -38.335974  144.742362
# 3977                       City of Casey  Cranbourne -38.113414  145.283332
#
# [121 rows x 6 columns]

# %%
#Import mapping file - use to filter to sample postcodes for further analysis
# Specify the file path and sheet name
file_path = "Resources/Melbourne Postcodes.xlsx"
sheet_name = "Mapping"

# Read the specified sheet into a DataFrame
melb_postcodes_df = pd.read_excel(file_path, sheet_name=sheet_name)
melb_postcodes_df= melb_postcodes_df.dropna(subset=['ABS_SA2_KEY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['HOUSE_LOCALITY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['SCHOOL_POST_CODE'])

#convert POST_CODE to string
melb_postcodes_df['POST_CODE'] = melb_postcodes_df['POST_CODE'].astype(str)
# Display the DataFrame
melb_postcodes_df
# Out:
#                                      MUNICIPALITY         CITY_SHIRE  \
# 0     Inner City municipalities and their suburbs  City of Melbourne
# 2     Inner City municipalities and their suburbs  City of Melbourne
# 6     Inner City municipalities and their suburbs  City of Melbourne
# 7     Inner City municipalities and their suburbs  City of Melbourne
# 10    Inner City municipalities and their suburbs  City of Melbourne
# ...                                           ...                ...
# 997      Western municipalities and their suburbs    City of Wyndham
# 1000     Western municipalities and their suburbs    City of Wyndham
# 1003     Western municipalities and their suburbs    City of Wyndham
# 1005     Western municipalities and their suburbs    City of Wyndham
# 1008     Western municipalities and their suburbs    City of Wyndham
#
#      SUBURB_GROUP    RURAL_TOWNSHIP POST_CODE  \
# 0           Inner               NaN      3053
# 2           Inner               NaN      3054
# 6           Inner               NaN      3031
# 7           Inner               NaN      3031
# 10          Inner               NaN      3051
# ...           ...               ...       ...
# 997         Outer               NaN      3030
# 1000        Outer               NaN      3030
# 1003        Outer               NaN      3024
# 1005        Outer  Rural localities      3338
# 1008        Outer  Rural localities      3024
#
#                                   ABS_SA2_KEY   HOUSE_LOCALITY  \
# 0                          206041117: Carlton          CARLTON
# 2     206071140: Carlton North - Princes Hill    CARLTON NORTH
# 6                       206031115: Flemington       FLEMINGTON
# 7                       206031115: Flemington       KENSINGTON
# 10                 206041506: North Melbourne  NORTH MELBOURNE
# ...                                       ...              ...
# 997                       213011570: Derrimut         WERRIBEE
# 1000                      213011570: Derrimut   WERRIBEE SOUTH
# 1003        213051579: Manor Lakes - Quandong     WYNDHAM VALE
# 1005                    213041571: Brookfield        EYNESBURY
# 1008        213051579: Manor Lakes - Quandong        MAMBOURIN
#
#       SCHOOL_POST_CODE      SUBURB_NAME                           COMMENTS  \
# 0               3053.0          Carlton                                NaN
# 2               3054.0    Carlton North          Shared with City of Yarra
# 6               3031.0       Flemington  Shared with City of Moonee Valley
# 7               3031.0       Kensington                                NaN
# 10              3051.0  North Melbourne  Shared with City of Moonee Valley
# ...                ...              ...                                ...
# 997             3030.0         Werribee                                NaN
# 1000            3030.0   Werribee South                                NaN
# 1003            3024.0     Wyndham Vale                                NaN
# 1005            3338.0        Eynesbury    Shared with the Shire of Melton
# 1008            3024.0        Mambourin                                NaN
#
#                                SUBURB_POSTCODE_COMMENTS
# 0                                          Carlton 3053
# 2        Carlton North 3054 (Shared with City of Yarra)
# 6     Flemington 3031 (Shared with City of Moonee Va...
# 7                                       Kensington 3031
# 10    North Melbourne 3051 (Shared with City of Moon...
# ...                                                 ...
# 997                                       Werribee 3030
# 1000                                Werribee South 3030
# 1003                                  Wyndham Vale 3024
# 1005   Eynesbury 3338 (Shared with the Shire of Melton)
# 1008                                     Mambourin 3024
#
# [405 rows x 11 columns]

# %%
# Concatenate SUBURB_NAME values for each POST_CODE
postcode_suburbs_df = melb_postcodes_df.groupby('POST_CODE')['SUBURB_NAME'].agg(lambda x: ', '.join(x)).reset_index()

# Display the resulting DataFrame
postcode_suburbs_df
# Out:
#     POST_CODE                                        SUBURB_NAME
# 0        3003                                     West Melbourne
# 1        3011                                  Footscray, Seddon
# 2        3012  Brooklyn, Brooklyn, Kingsville, Maidstone, Wes...
# 3        3013                  Yarraville, Aintree, Bonnie Brook
# 4        3015               Newport, Spotswood, South Kingsville
# ..        ...                                                ...
# 188      3975                                Lynbrook, Lyndhurst
# 189      3976                                       Hampton Park
# 190      3977  Botanic Ridge, Cranbourne, Cranbourne East, Cr...
# 191      3978                                 Clyde, Clyde North
# 192      3981                                        Koo Wee Rup
#
# [193 rows x 2 columns]

# %%
police_clean_1_df = pd.merge(melb_postcodes_df, police_df, how='right', on='POST_CODE')

police_clean_1_df= police_clean_1_df.dropna(subset=['HOUSE_LOCALITY'])

columns_to_drop = ["RURAL_TOWNSHIP","ABS_SA2_KEY","HOUSE_LOCALITY","SCHOOL_POST_CODE",
                   "COMMENTS","SUBURB_NAME","SUBURB_POSTCODE_COMMENTS","Address","Municipality"]

police_clean_1_df = police_clean_1_df.drop(columns_to_drop, axis=1)
# Remove duplicates based on the "POST_CODE" column
police_clean_1_df = police_clean_1_df.drop_duplicates(subset='POST_CODE')

police_clean_1_df
# Out:
#                                       MUNICIPALITY  \
# 7         Western municipalities and their suburbs
# 9         Western municipalities and their suburbs
# 11        Western municipalities and their suburbs
# 13        Western municipalities and their suburbs
# 17        Western municipalities and their suburbs
# ..                                             ...
# 229  Southeastern municipalities and their suburbs
# 231  Southeastern municipalities and their suburbs
# 232  Southeastern municipalities and their suburbs
# 234  Southeastern municipalities and their suburbs
# 240  Southeastern municipalities and their suburbs
#
#                         CITY_SHIRE SUBURB_GROUP POST_CODE  \
# 7              City of Maribyrnong          Mid      3011
# 9              City of Hobsons Bay          Mid      3016
# 11             City of Hobsons Bay          Mid      3018
# 13                City of Brimbank          Mid      3020
# 17                City of Brimbank          Mid      3023
# ..                             ...          ...       ...
# 229  Shire of Mornington Peninsula        Outer      3915
# 231  Shire of Mornington Peninsula        Outer      3931
# 232  Shire of Mornington Peninsula        Outer      3936
# 234  Shire of Mornington Peninsula        Outer      3939
# 240                  City of Casey        Outer      3977
#
#                                 NAME            Suburb   Latitude   Longitude
# 7           Footscray Police Station         Footscray -37.803927  144.901194
# 9        Williamstown Police Station      Williamstown -37.863315  144.906381
# 11             Altona Police Station            Altona -37.863222  144.810077
# 13           Sunshine Police Station          Sunshine -37.777910  144.831231
# 17   Caroline Springs Police Station  Caroline Springs -37.730629  144.741205
# ..                               ...               ...        ...         ...
# 229          Hastings Police Station              None -38.307951  145.184646
# 231        Mornington Police Station        Mornington -38.216367  145.036895
# 232           Dromana Police Station           Dromana -38.334746  144.961068
# 234           Rosebud Police Station           Rosebud -38.369808  144.889915
# 240                       Cranbourne        Cranbourne -38.113414  145.283332
#
# [84 rows x 8 columns]

# %%
unique_count = police_clean_1_df['POST_CODE'].nunique()

# Display the count of unique strings
print(unique_count)
# Out:
# 84

# %%
police_clean_final_df = pd.merge(police_clean_1_df, postcode_suburbs_df, how='inner', on='POST_CODE')
new_column_names = {
    "SUBURB_NAME": "SUBURB_NAMES",
    }
police_clean_final_df = police_clean_final_df.rename(columns=new_column_names)

# Reset the index and make POST_CODE the new index
police_clean_final_df = police_clean_final_df.set_index('POST_CODE')

# Export cleaned population dataset to a CSV file
police_clean_final_df.to_csv("Cleaned_Data/police_clean_final.csv", index_label="POST_CODE")

police_clean_final_df
# Out:
#                                             MUNICIPALITY  \
# POST_CODE
# 3011            Western municipalities and their suburbs
# 3016            Western municipalities and their suburbs
# 3018            Western municipalities and their suburbs
# 3020            Western municipalities and their suburbs
# 3023            Western municipalities and their suburbs
# ...                                                  ...
# 3915       Southeastern municipalities and their suburbs
# 3931       Southeastern municipalities and their suburbs
# 3936       Southeastern municipalities and their suburbs
# 3939       Southeastern municipalities and their suburbs
# 3977       Southeastern municipalities and their suburbs
#
#                               CITY_SHIRE SUBURB_GROUP  \
# POST_CODE
# 3011                 City of Maribyrnong          Mid
# 3016                 City of Hobsons Bay          Mid
# 3018                 City of Hobsons Bay          Mid
# 3020                    City of Brimbank          Mid
# 3023                    City of Brimbank          Mid
# ...                                  ...          ...
# 3915       Shire of Mornington Peninsula        Outer
# 3931       Shire of Mornington Peninsula        Outer
# 3936       Shire of Mornington Peninsula        Outer
# 3939       Shire of Mornington Peninsula        Outer
# 3977                       City of Casey        Outer
#
#                                       NAME            Suburb   Latitude  \
# POST_CODE
# 3011              Footscray Police Station         Footscray -37.803927
# 3016           Williamstown Police Station      Williamstown -37.863315
# 3018                 Altona Police Station            Altona -37.863222
# 3020               Sunshine Police Station          Sunshine -37.777910
# 3023       Caroline Springs Police Station  Caroline Springs -37.730629
# ...                                    ...               ...        ...
# 3915               Hastings Police Station              None -38.307951
# 3931             Mornington Police Station        Mornington -38.216367
# 3936                Dromana Police Station           Dromana -38.334746
# 3939                Rosebud Police Station           Rosebud -38.369808
# 3977                            Cranbourne        Cranbourne -38.113414
#
#             Longitude                                       SUBURB_NAMES
# POST_CODE
# 3011       144.901194                                  Footscray, Seddon
# 3016       144.906381                   Williamstown, Williamstown North
# 3018       144.810077                                   Altona, Seaholme
# 3020       144.831231    Albion, Sunshine, Sunshine North, Sunshine West
# 3023       144.741205  Cairnlea, Deer Park, Burnside, Burnside Height...
# ...               ...                                                ...
# 3915       145.184646                            Hastings, Hastings West
# 3931       145.036895                                         Mornington
# 3936       144.961068                              Dromana, Safety Beach
# 3939       144.889915       Rosebud, Rosebud South, Cape Schanck, Fingal
# 3977       145.283332  Botanic Ridge, Cranbourne, Cranbourne East, Cr...
#
# [84 rows x 8 columns]

# %%
# Group the hospitals_clean_final_df by the specified columns and count the occurrences of NAME
police_count_by_postcode_df = police_clean_final_df.groupby(['POST_CODE', 'MUNICIPALITY', 'CITY_SHIRE', 'SUBURB_GROUP'])['NAME'].count().reset_index()

# Rename the count column to "Hospital_Count"
police_count_by_postcode_df = police_count_by_postcode_df.rename(columns={'NAME': 'Police_Count'})

# Export the hospital count by postcode to a CSV file
police_count_by_postcode_df.to_csv("Cleaned_Data/police_count_by_postcode.csv", index=False)

# Display the hospital count DataFrame
police_count_by_postcode_df
# Out:
#    POST_CODE                                   MUNICIPALITY  \
# 0       3011       Western municipalities and their suburbs
# 1       3016       Western municipalities and their suburbs
# 2       3018       Western municipalities and their suburbs
# 3       3020       Western municipalities and their suburbs
# 4       3023       Western municipalities and their suburbs
# ..       ...                                            ...
# 79      3915  Southeastern municipalities and their suburbs
# 80      3931  Southeastern municipalities and their suburbs
# 81      3936  Southeastern municipalities and their suburbs
# 82      3939  Southeastern municipalities and their suburbs
# 83      3977  Southeastern municipalities and their suburbs
#
#                        CITY_SHIRE SUBURB_GROUP  Police_Count
# 0             City of Maribyrnong          Mid             1
# 1             City of Hobsons Bay          Mid             1
# 2             City of Hobsons Bay          Mid             1
# 3                City of Brimbank          Mid             1
# 4                City of Brimbank          Mid             1
# ..                            ...          ...           ...
# 79  Shire of Mornington Peninsula        Outer             1
# 80  Shire of Mornington Peninsula        Outer             1
# 81  Shire of Mornington Peninsula        Outer             1
# 82  Shire of Mornington Peninsula        Outer             1
# 83                  City of Casey        Outer             1
#
# [84 rows x 5 columns]
