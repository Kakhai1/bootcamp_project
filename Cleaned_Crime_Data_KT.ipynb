# %% [markdown]
# # Clean Crime Data

# %%
# Import the required libraries
import requests
import json
import pandas as pd

# %%
#Import crime by suburb data
#encodings = ['utf-8', 'utf-8-sig', 'latin-1', 'cp1252', 'utf-16']

# Specify the file path and sheet name
file_path = "Resources\Data_Tables_LGA_Criminal_Incidents_Year_Ending_March_2023.xlsx"
sheet_name = "Table 03"

# Read the Excel file, specifying the sheet name and header row
crime_df = pd.read_excel(file_path, sheet_name, header=[0])

# Define the columns to drop
columns_to_drop = ["Year ending", "Local Government Area", "Suburb/Town Name"]

# Drop the specified columns
crime_df = crime_df.drop(columns_to_drop, axis=1)

# Rename the columns
new_column_names = {
    "Postcode": "POST_CODE"
}
crime_df = crime_df.rename(columns=new_column_names)

# Display the updated DataFrame
crime_df
# Out:
#         Year  POST_CODE                      Offence Division  \
# 0       2023       3691           A Crimes against the person
# 1       2023       3691           A Crimes against the person
# 2       2023       3691     B Property and deception offences
# 3       2023       3691     B Property and deception offences
# 4       2023       3691  D Public order and security offences
# ...      ...        ...                                   ...
# 330929  2014       3489     B Property and deception offences
# 330930  2014       3489     B Property and deception offences
# 330931  2014       3489         E Justice procedures offences
# 330932  2014       3491           A Crimes against the person
# 330933  2014       3491           A Crimes against the person
#
#                         Offence Subdivision  \
# 0          A20 Assault and related offences
# 1           Other crimes against the person
# 2                                 B40 Theft
# 3                                 B40 Theft
# 4       D10 Weapons and explosives offences
# ...                                     ...
# 330929                  B20 Property damage
# 330930         B30 Burglary/Break and enter
# 330931               E20 Breaches of orders
# 330932     A20 Assault and related offences
# 330933      Other crimes against the person
#
#                                     Offence Subgroup  Incidents Recorded
# 0                        A212 Non-FV Serious assault                   1
# 1                    Other crimes against the person                   1
# 2                     B42 Steal from a motor vehicle                   2
# 3                                    B49 Other theft                   1
# 4                              D11 Firearms offences                   1
# ...                                              ...                 ...
# 330929                           B21 Criminal damage                   1
# 330930  B322 Non-residential non-aggravated burglary                   1
# 330931                 E22 Breach intervention order                   1
# 330932                   A212 Non-FV Serious assault                   1
# 330933               Other crimes against the person                   1
#
# [330934 rows x 6 columns]

# %%
#Import mapping file - use to filter to sample postcodes for further analysis
# Specify the file path and sheet name
file_path = "Resources/Melbourne Postcodes.xlsx"
sheet_name = "Mapping"

# Read the specified sheet into a DataFrame
melb_postcodes_df = pd.read_excel(file_path, sheet_name=sheet_name)
melb_postcodes_df= melb_postcodes_df.dropna(subset=['ABS_SA2_KEY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['HOUSE_LOCALITY'])
melb_postcodes_df= melb_postcodes_df.dropna(subset=['SCHOOL_POST_CODE'])

# Display the DataFrame
melb_postcodes_df
# Out:
#                                      MUNICIPALITY             CITY_SHIRE  \
# 0     Inner City municipalities and their suburbs      City of Melbourne
# 2     Inner City municipalities and their suburbs          City of Yarra
# 6       Northern municipalities and their suburbs  City of Moonee Valley
# 7       Northern municipalities and their suburbs  City of Moonee Valley
# 10    Inner City municipalities and their suburbs      City of Melbourne
# ...                                           ...                    ...
# 997      Western municipalities and their suburbs        City of Wyndham
# 1000     Western municipalities and their suburbs        City of Wyndham
# 1003     Western municipalities and their suburbs        City of Wyndham
# 1005     Western municipalities and their suburbs         City of Melton
# 1008     Western municipalities and their suburbs        City of Wyndham
#
#      SUBURB_GROUP    RURAL_TOWNSHIP  POST_CODE  \
# 0           Inner               NaN       3053
# 2           Inner               NaN       3054
# 6             Mid               NaN       3031
# 7             Mid               NaN       3031
# 10          Inner               NaN       3051
# ...           ...               ...        ...
# 997         Outer               NaN       3030
# 1000        Outer               NaN       3030
# 1003        Outer               NaN       3024
# 1005        Outer  Rural localities       3338
# 1008        Outer  Rural localities       3024
#
#                                   ABS_SA2_KEY   HOUSE_LOCALITY  \
# 0                          206041117: Carlton          CARLTON
# 2     206071140: Carlton North - Princes Hill    CARLTON NORTH
# 6                       206031115: Flemington       FLEMINGTON
# 7                       206031115: Flemington       KENSINGTON
# 10                 206041506: North Melbourne  NORTH MELBOURNE
# ...                                       ...              ...
# 997                       213011570: Derrimut         WERRIBEE
# 1000                      213011570: Derrimut   WERRIBEE SOUTH
# 1003        213051579: Manor Lakes - Quandong     WYNDHAM VALE
# 1005                    213041571: Brookfield        EYNESBURY
# 1008        213051579: Manor Lakes - Quandong        MAMBOURIN
#
#       SCHOOL_POST_CODE      SUBURB_NAME                           COMMENTS  \
# 0               3053.0          Carlton                                NaN
# 2               3054.0    Carlton North          Shared with City of Yarra
# 6               3031.0       Flemington  Shared with City of Moonee Valley
# 7               3031.0       Kensington                                NaN
# 10              3051.0  North Melbourne  Shared with City of Moonee Valley
# ...                ...              ...                                ...
# 997             3030.0         Werribee                                NaN
# 1000            3030.0   Werribee South                                NaN
# 1003            3024.0     Wyndham Vale                                NaN
# 1005            3338.0        Eynesbury    Shared with the Shire of Melton
# 1008            3024.0        Mambourin                                NaN
#
#                                SUBURB_POSTCODE_COMMENTS
# 0                                          Carlton 3053
# 2        Carlton North 3054 (Shared with City of Yarra)
# 6     Flemington 3031 (Shared with City of Moonee Va...
# 7                                       Kensington 3031
# 10    North Melbourne 3051 (Shared with City of Moon...
# ...                                                 ...
# 997                                       Werribee 3030
# 1000                                Werribee South 3030
# 1003                                  Wyndham Vale 3024
# 1005   Eynesbury 3338 (Shared with the Shire of Melton)
# 1008                                     Mambourin 3024
#
# [405 rows x 11 columns]

# %%
# Concatenate SUBURB_NAME values for each POST_CODE
postcode_suburbs_df = melb_postcodes_df.groupby('POST_CODE')['SUBURB_NAME'].agg(lambda x: ', '.join(x)).reset_index()

# Display the resulting DataFrame
postcode_suburbs_df
# Out:
#      POST_CODE                                        SUBURB_NAME
# 0         3003                                     West Melbourne
# 1         3011                                  Footscray, Seddon
# 2         3012  Brooklyn, Brooklyn, Kingsville, Maidstone, Wes...
# 3         3013                  Yarraville, Aintree, Bonnie Brook
# 4         3015               Newport, Spotswood, South Kingsville
# ..         ...                                                ...
# 188       3975                                Lynbrook, Lyndhurst
# 189       3976                                       Hampton Park
# 190       3977  Botanic Ridge, Cranbourne, Cranbourne East, Cr...
# 191       3978                                 Clyde, Clyde North
# 192       3981                                        Koo Wee Rup
#
# [193 rows x 2 columns]

# %%
crime_clean_1_df = pd.merge(melb_postcodes_df, crime_df, how='inner', on='POST_CODE')
columns_to_drop = ["RURAL_TOWNSHIP","ABS_SA2_KEY","HOUSE_LOCALITY","SCHOOL_POST_CODE",
                   "COMMENTS","SUBURB_NAME","SUBURB_POSTCODE_COMMENTS"]
crime_clean_1_df = crime_clean_1_df.drop(columns_to_drop, axis=1)
crime_clean_1_df = crime_clean_1_df.drop_duplicates()
crime_clean_1_df
# Out:
#                                        MUNICIPALITY         CITY_SHIRE  \
# 0       Inner City municipalities and their suburbs  City of Melbourne
# 1       Inner City municipalities and their suburbs  City of Melbourne
# 2       Inner City municipalities and their suburbs  City of Melbourne
# 3       Inner City municipalities and their suburbs  City of Melbourne
# 4       Inner City municipalities and their suburbs  City of Melbourne
# ...                                             ...                ...
# 418251     Western municipalities and their suburbs    City of Wyndham
# 418252     Western municipalities and their suburbs    City of Wyndham
# 418253     Western municipalities and their suburbs    City of Wyndham
# 418254     Western municipalities and their suburbs    City of Wyndham
# 418255     Western municipalities and their suburbs    City of Wyndham
#
#        SUBURB_GROUP  POST_CODE  Year                      Offence Division  \
# 0             Inner       3053  2023           A Crimes against the person
# 1             Inner       3053  2023           A Crimes against the person
# 2             Inner       3053  2023           A Crimes against the person
# 3             Inner       3053  2023           A Crimes against the person
# 4             Inner       3053  2023           A Crimes against the person
# ...             ...        ...   ...                                   ...
# 418251        Outer       3024  2014  D Public order and security offences
# 418252        Outer       3024  2014  D Public order and security offences
# 418253        Outer       3024  2014         E Justice procedures offences
# 418254        Outer       3024  2014         E Justice procedures offences
# 418255        Outer       3024  2014         E Justice procedures offences
#
#                      Offence Subdivision  \
# 0       A20 Assault and related offences
# 1       A20 Assault and related offences
# 2       A20 Assault and related offences
# 3       A20 Assault and related offences
# 4       A20 Assault and related offences
# ...                                  ...
# 418251      D30 Public nuisance offences
# 418252      D30 Public nuisance offences
# 418253            E10 Justice procedures
# 418254            E20 Breaches of orders
# 418255            E20 Breaches of orders
#
#                                          Offence Subgroup  Incidents Recorded
# 0                                 A211 FV Serious assault                  22
# 1                             A212 Non-FV Serious assault                  47
# 2       A22 Assault police, emergency services or othe...                  10
# 3                                  A231 FV Common assault                  37
# 4                              A232 Non-FV Common assault                  61
# ...                                                   ...                 ...
# 418251   D35 Improper movement on public or private space                   1
# 418252                 D36 Other public nuisance offences                   1
# 418253  E14 Pervert the course of justice or commit pe...                   1
# 418254                   E21 Breach family violence order                  24
# 418255                         E23 Breach bail conditions                   1
#
# [143727 rows x 9 columns]

# %%
crime_clean_final_df = pd.merge(crime_clean_1_df, postcode_suburbs_df, how='inner', on='POST_CODE')
new_column_names = {
    "SUBURB_NAME": "SUBURB_NAMES",
    }
crime_clean_final_df = crime_clean_final_df.rename(columns=new_column_names)
crime_clean_final_df
# Out:
#                                        MUNICIPALITY         CITY_SHIRE  \
# 0       Inner City municipalities and their suburbs  City of Melbourne
# 1       Inner City municipalities and their suburbs  City of Melbourne
# 2       Inner City municipalities and their suburbs  City of Melbourne
# 3       Inner City municipalities and their suburbs  City of Melbourne
# 4       Inner City municipalities and their suburbs  City of Melbourne
# ...                                             ...                ...
# 143722     Western municipalities and their suburbs    City of Wyndham
# 143723     Western municipalities and their suburbs    City of Wyndham
# 143724     Western municipalities and their suburbs    City of Wyndham
# 143725     Western municipalities and their suburbs    City of Wyndham
# 143726     Western municipalities and their suburbs    City of Wyndham
#
#        SUBURB_GROUP  POST_CODE  Year                      Offence Division  \
# 0             Inner       3053  2023           A Crimes against the person
# 1             Inner       3053  2023           A Crimes against the person
# 2             Inner       3053  2023           A Crimes against the person
# 3             Inner       3053  2023           A Crimes against the person
# 4             Inner       3053  2023           A Crimes against the person
# ...             ...        ...   ...                                   ...
# 143722        Outer       3024  2014  D Public order and security offences
# 143723        Outer       3024  2014  D Public order and security offences
# 143724        Outer       3024  2014         E Justice procedures offences
# 143725        Outer       3024  2014         E Justice procedures offences
# 143726        Outer       3024  2014         E Justice procedures offences
#
#                      Offence Subdivision  \
# 0       A20 Assault and related offences
# 1       A20 Assault and related offences
# 2       A20 Assault and related offences
# 3       A20 Assault and related offences
# 4       A20 Assault and related offences
# ...                                  ...
# 143722      D30 Public nuisance offences
# 143723      D30 Public nuisance offences
# 143724            E10 Justice procedures
# 143725            E20 Breaches of orders
# 143726            E20 Breaches of orders
#
#                                          Offence Subgroup  Incidents Recorded  \
# 0                                 A211 FV Serious assault                  22
# 1                             A212 Non-FV Serious assault                  47
# 2       A22 Assault police, emergency services or othe...                  10
# 3                                  A231 FV Common assault                  37
# 4                              A232 Non-FV Common assault                  61
# ...                                                   ...                 ...
# 143722   D35 Improper movement on public or private space                   1
# 143723                 D36 Other public nuisance offences                   1
# 143724  E14 Pervert the course of justice or commit pe...                   1
# 143725                   E21 Breach family violence order                  24
# 143726                         E23 Breach bail conditions                   1
#
#                                 SUBURB_NAMES
# 0                                    Carlton
# 1                                    Carlton
# 2                                    Carlton
# 3                                    Carlton
# 4                                    Carlton
# ...                                      ...
# 143722  Manor Lakes, Wyndham Vale, Mambourin
# 143723  Manor Lakes, Wyndham Vale, Mambourin
# 143724  Manor Lakes, Wyndham Vale, Mambourin
# 143725  Manor Lakes, Wyndham Vale, Mambourin
# 143726  Manor Lakes, Wyndham Vale, Mambourin
#
# [143727 rows x 10 columns]

# %%
unique_count = crime_clean_final_df['POST_CODE'].nunique()

# Display the count of unique strings
print(unique_count)
# Out:
# 193

# %%
# Check for NaN values in a column
has_nan = crime_clean_final_df['Incidents Recorded'].isna().any()

# Display the result - False (no NaN values in column), True (at least one NaN value in column)
print(has_nan)
# Out:
# False

# %%
crime_clean_final_df = crime_clean_final_df.drop_duplicates()
# Reset the index and make POST_CODE the new index
crime_clean_final_df = crime_clean_final_df.set_index('POST_CODE')

# Export cleaned population dataset to a CSV file
crime_clean_final_df.to_csv("Cleaned_Data/crime_clean_final.csv", index_label="POST_CODE")
crime_clean_final_df
# Out:
#                                           MUNICIPALITY         CITY_SHIRE  \
# POST_CODE
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# 3053       Inner City municipalities and their suburbs  City of Melbourne
# ...                                                ...                ...
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
# 3024          Western municipalities and their suburbs    City of Wyndham
#
#           SUBURB_GROUP  Year                      Offence Division  \
# POST_CODE
# 3053             Inner  2023           A Crimes against the person
# 3053             Inner  2023           A Crimes against the person
# 3053             Inner  2023           A Crimes against the person
# 3053             Inner  2023           A Crimes against the person
# 3053             Inner  2023           A Crimes against the person
# ...                ...   ...                                   ...
# 3024             Outer  2014  D Public order and security offences
# 3024             Outer  2014  D Public order and security offences
# 3024             Outer  2014         E Justice procedures offences
# 3024             Outer  2014         E Justice procedures offences
# 3024             Outer  2014         E Justice procedures offences
#
#                         Offence Subdivision  \
# POST_CODE
# 3053       A20 Assault and related offences
# 3053       A20 Assault and related offences
# 3053       A20 Assault and related offences
# 3053       A20 Assault and related offences
# 3053       A20 Assault and related offences
# ...                                     ...
# 3024           D30 Public nuisance offences
# 3024           D30 Public nuisance offences
# 3024                 E10 Justice procedures
# 3024                 E20 Breaches of orders
# 3024                 E20 Breaches of orders
#
#                                             Offence Subgroup  \
# POST_CODE
# 3053                                 A211 FV Serious assault
# 3053                             A212 Non-FV Serious assault
# 3053       A22 Assault police, emergency services or othe...
# 3053                                  A231 FV Common assault
# 3053                              A232 Non-FV Common assault
# ...                                                      ...
# 3024        D35 Improper movement on public or private space
# 3024                      D36 Other public nuisance offences
# 3024       E14 Pervert the course of justice or commit pe...
# 3024                        E21 Breach family violence order
# 3024                              E23 Breach bail conditions
#
#            Incidents Recorded                          SUBURB_NAMES
# POST_CODE
# 3053                       22                               Carlton
# 3053                       47                               Carlton
# 3053                       10                               Carlton
# 3053                       37                               Carlton
# 3053                       61                               Carlton
# ...                       ...                                   ...
# 3024                        1  Manor Lakes, Wyndham Vale, Mambourin
# 3024                        1  Manor Lakes, Wyndham Vale, Mambourin
# 3024                        1  Manor Lakes, Wyndham Vale, Mambourin
# 3024                       24  Manor Lakes, Wyndham Vale, Mambourin
# 3024                        1  Manor Lakes, Wyndham Vale, Mambourin
#
# [143727 rows x 9 columns]
